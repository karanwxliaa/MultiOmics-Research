# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import os
import sys

# %%
import STAGATE

# %% [markdown]
# Reading Data (Stereo)

# %%
file_fold = r'C:\Users\AGNISH\Desktop\IITK\VSCode\SpatialGlue\Data\Mouse_Thymus'
gdata = sc.read_h5ad(file_fold + '/adata_RNA.h5ad')
gdata.var_names_make_unique()

# %%
gdata
# Out:
# AnnData object with n_obs × n_vars = 4697 × 23622
#     obs: 'orig.ident', 'x', 'y'
#     obsm: 'spatial'

# %%
file_fold = r'C:\Users\AGNISH\Desktop\IITK\VSCode\SpatialGlue\Data\Mouse_Thymus'
pdata = sc.read_h5ad(file_fold + '/adata_ADT.h5ad')
pdata.var_names_make_unique()

# %%
pdata
# Out:
# AnnData object with n_obs × n_vars = 4697 × 51
#     obs: 'orig.ident', 'x', 'y'
#     obsm: 'spatial'

# %%
gdata.X
# Out:
# <4697x23622 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5108108 stored elements in Compressed Sparse Row format>

# %%
pdata.X
# Out:
# <4697x51 sparse matrix of type '<class 'numpy.float64'>'
# 	with 70786 stored elements in Compressed Sparse Row format>

# %%
gdata.obs['orig.ident']
# Out:
# 0_22    sample
# 0_33    sample
# 0_40    sample
# 0_41    sample
# 0_42    sample
#          ...
# 9_73    sample
# 9_74    sample
# 9_75    sample
# 9_8     sample
# 9_9     sample
# Name: orig.ident, Length: 4697, dtype: category
# Categories (1, object): ['sample']

# %% [markdown]
# Reading data (Landau)

# %%
# file = r'C:\Users\AGNISH\Desktop\IITK\VSCode\STAGATE\Landau\SPOTS Landau paper dataset\spleen_rep_1'
# adata = sc.read_visium(file, count_file=r'GSE198353_spleen_rep_1_filtered_feature_bc_matrix.h5',load_images=True)
# adata.var_names_make_unique()

# %%
# file_fold = 'C:/Users/AGNISH/Desktop/IITK/VSCode/SpatialGlue/Data/Mouse_Spleen/'
# gdata = sc.read_h5ad(file_fold + 'adata_RNA.h5ad')
# gdata.var_names_make_unique()

# %%
# gdata

# %%
# file_fold = 'C:/Users/AGNISH/Desktop/IITK/VSCode/SpatialGlue/Data/Mouse_Spleen/'
# pdata = sc.read_h5ad(file_fold + 'adata_Pro.h5ad')
# pdata.var_names_make_unique()

# %%
# pdata

# %%
# gdata.obsm=adata.obsm
# gdata.uns = adata.uns
# pdata.obsm=adata.obsm
# pdata.uns = adata.uns

# %%
#Normalization
sc.pp.highly_variable_genes(gdata, flavor="seurat_v3", n_top_genes=3000)
sc.pp.normalize_total(gdata, target_sum=1e4)
sc.pp.log1p(gdata)

# %%
#Normalization
#sc.pp.highly_variable_genes(adata, flavor="seurat_v3", n_top_genes=3000)
#sc.pp.normalize_total(pdata, target_sum=1e4)
sc.pp.log1p(pdata)

# %%
gdata
# Out:
# AnnData object with n_obs × n_vars = 4697 × 23622
#     obs: 'orig.ident', 'x', 'y'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'hvg', 'log1p'
#     obsm: 'spatial'

# %%
pdata
# Out:
# AnnData object with n_obs × n_vars = 4697 × 51
#     obs: 'orig.ident', 'x', 'y'
#     uns: 'log1p'
#     obsm: 'spatial'

# %% [markdown]
# Functions

# %%
import tensorflow as tf

class LinBnDrop(tf.keras.Sequential):
    def __init__(self, n_in, n_out, bn=True, p=0., act=None, lin_first=True):
        layers = []
        if bn:
            layers.append(tf.keras.layers.BatchNormalization())
        if p != 0:
            layers.append(tf.keras.layers.Dropout(p))
        lin = [tf.keras.layers.Dense(n_out, use_bias=not bn)]
        if act is not None:
            layers.append(act)
        layers = lin + layers if lin_first else layers + lin
        super(LinBnDrop, self).__init__(layers)

# %%
import tensorflow as tf
import tensorflow.compat.v1 as v1


class GATE():
    def __init__(self, hidden_dims1, hidden_dims2,z_dim=30,a=0.05,alpha=0.3, nonlinear=True, weight_decay=0.0001, num_hidden=256, num_proj_hidden=256, tau=0.5):
        self.n_layers1 = len(hidden_dims1) - 1
        self.n_layers2 = len(hidden_dims2) - 1
        self.alpha = alpha
        self.W1, self.v1, self.prune_v1 = self.define_weights1(hidden_dims1, self.n_layers1)
        self.W2, self.v2, self.prune_v2 = self.define_weights2(hidden_dims2, self.n_layers2)
        self.C1 = {}
        self.C2 = {}
        self.prune_C1 = {}
        self.prune_C2 = {}
        self.nonlinear = nonlinear
        self.weight_decay = weight_decay
        self.z_dim = z_dim
        self.fc_mu = LinBnDrop(z_dim,z_dim, p=0.2)
        self.fc_var = LinBnDrop(z_dim,z_dim, p=0.2)
        self.a = a
        self.tau = tau
        self.fc1 = tf.keras.layers.Dense(num_proj_hidden, activation='elu')
        self.fc2 = tf.keras.layers.Dense(num_hidden)

        # Decoder 1
        self.W_dec1 = {}
        for layer in range(self.n_layers1 - 1, -1, -1):
            self.W_dec1[layer] = tf.Variable(tf.random.normal([hidden_dims1[layer+1], hidden_dims1[layer]]))

        # Decoder 2
        self.W_dec2 = {}
        for layer in range(self.n_layers2 - 1, -1, -1):
            self.W_dec2[layer] = tf.Variable(tf.random.normal([hidden_dims2[layer+1], hidden_dims2[layer]]))

    def __call__(self, A1,A2 ,prune_A1,prune_A2, X1,X2):
        # Encoder 1
        H1 = X1
        for layer in range(self.n_layers1):
            H1 = self.__encoder1(A1, prune_A1, H1, layer)
            if self.nonlinear:
                if layer != self.n_layers1 - 1:
                    H1 = tf.nn.elu(H1)

        # Encoder 2
        H2 = X2
        for layer in range(self.n_layers2):
            H2 = self.__encoder2(A2, prune_A2, H2, layer)
            if self.nonlinear:
                if layer != self.n_layers2 - 1:
                    H2 = tf.nn.elu(H2)

        con_loss = self.con_loss(H1, H2, batch_size=0)

        self.c_loss = con_loss

        # Concatenate encoder outputs
        H = tf.concat([H1, H2], axis=1)

        # Call the third encoder
        global latent_rep 
        H = self.__encoder3(H)

        #Latent space using a varational auto encoder
        mu = self.fc_mu(H)
        var = self.fc_var(H)
        H = self.reparameterize(mu, var)
        
        latent_rep = H

        # KL Divergence Loss
        kl_loss = -0.5 * tf.reduce_sum(1 + var - tf.square(mu) - tf.exp(var), axis=1)
        kl_loss = tf.reduce_mean(kl_loss)


        temp=H
        H1=temp
        # Decoder 1
        for layer in range(self.n_layers1 - 1, -1, -1):
            H1 = self.__decoder1(H1, layer)
            if self.nonlinear:
                if layer != 0:
                    H1 = tf.nn.elu(H1)
        X1_ = H1

        H2=temp
        # Decoder 2
        for layer1 in range(self.n_layers2 - 1, -1, -1):
            H2 = self.__decoder2(H2, layer1)
            if self.nonlinear:
                if layer1 != 0:
                    H2 = tf.nn.elu(H2)
        X2_ = H2

        # Loss calculation
        features_loss = tf.sqrt(tf.reduce_sum(tf.pow(X1 - X1_, 2)))
        features_loss += tf.sqrt(tf.reduce_sum(tf.pow(X2 - X2_, 2)))



        weight_decay_loss = 0
        for layer in range(self.n_layers1):
            weight_decay_loss += tf.multiply(tf.nn.l2_loss(self.W1[layer]), self.weight_decay, name='weight_loss')
        for layer in range(self.n_layers2):
            weight_decay_loss += tf.multiply(tf.nn.l2_loss(self.W2[layer]), self.weight_decay, name='weight_loss')
        for layer in range(self.n_layers1):
            weight_decay_loss += tf.multiply(tf.nn.l2_loss(self.W_dec1[layer]), self.weight_decay, name='weight_loss')
        for layer in range(self.n_layers2):
            weight_decay_loss += tf.multiply(tf.nn.l2_loss(self.W_dec2[layer]), self.weight_decay, name='weight_loss')

        # Total loss
        self.loss = 10*con_loss + features_loss + weight_decay_loss + self.a*kl_loss

        if self.alpha == 0:
            self.Att_l = {'C1': self.C1, 'C2': self.C2}
        else:
            self.Att_l = {'C1': self.C1, 'C2': self.C2, 'prune_C1': self.prune_C1, 'prune_C2': self.prune_C2}

        return self.c_loss, self.loss, latent_rep, self.Att_l, X1_, X2_
    
    def projection(self, z):
        z = self.fc1(z)
        return self.fc2(z)

    def sim(self, z1, z2):
        z1 = tf.nn.l2_normalize(z1, axis=1)
        z2 = tf.nn.l2_normalize(z2, axis=1)
        return tf.matmul(z1, z2, transpose_b=True)

    def semi_loss(self, z1, z2):
        f = lambda x: tf.exp(x / self.tau)
        refl_sim = f(self.sim(z1, z1))
        between_sim = f(self.sim(z1, z2))
        diag_ref_sim = tf.linalg.diag_part(refl_sim)

        return -tf.math.log(
            tf.linalg.diag_part(between_sim)
            / (tf.reduce_sum(refl_sim, axis=1) + tf.reduce_sum(between_sim, axis=1) - diag_ref_sim))

    def batched_semi_loss(self, z1, z2, batch_size):
        num_nodes = tf.shape(z1)[0]
        num_batches = (num_nodes - 1) // batch_size + 1
        f = lambda x: tf.exp(x / self.tau)
        indices = tf.range(0, num_nodes)
        losses = []

        for i in range(num_batches):
            mask = indices[i * batch_size:(i + 1) * batch_size]
            refl_sim = f(self.sim(tf.gather(z1, mask), z1))  # [B, N]
            between_sim = f(self.sim(tf.gather(z1, mask), z2))  # [B, N]

            losses.append(-tf.math.log(
                tf.linalg.diag_part(tf.gather(between_sim, mask, batch_dims=1))
                / (tf.reduce_sum(refl_sim, axis=1) + tf.reduce_sum(between_sim, axis=1)
                   - tf.linalg.diag_part(tf.gather(refl_sim, mask, batch_dims=1)))))

        return tf.concat(losses, axis=0)

    def con_loss(self, z1, z2, mean=True, batch_size=0):
        h1 = self.projection(z1)
        h2 = self.projection(z2)

        if batch_size == 0:
            l1 = self.semi_loss(h1, h2)
            l2 = self.semi_loss(h2, h1)
        else:
            l1 = self.batched_semi_loss(h1, h2, batch_size)
            l2 = self.batched_semi_loss(h2, h1, batch_size)

        ret = (l1 + l2) * 0.5
        ret = tf.reduce_mean(ret) if mean else tf.reduce_sum(ret)

        return ret
    

    def reparameterize(self, mu, logvar):
        std = tf.exp(0.5 * logvar)
        eps = tf.random.normal(shape=tf.shape(std))
        return eps * std + mu

    def __encoder1(self, A, prune_A1, H, layer):
        print('enc1 = ',H)
        H = tf.matmul(H, self.W1[layer])
        if layer == self.n_layers1 - 1:
            return H
        self.C1[layer] = self.graph_attention_layer(A, H, self.v1[layer], layer)
        if self.alpha == 0:
            return tf.sparse.sparse_dense_matmul(self.C1[layer], H)
        else:
            self.prune_C1[layer] = self.graph_attention_layer(prune_A1, H, self.prune_v1[layer], layer)
            return (1 - self.alpha) * tf.sparse.sparse_dense_matmul(self.C1[layer], H) + self.alpha * tf.sparse.sparse_dense_matmul(
                self.prune_C1[layer], H)
        
        

    def __encoder2(self, A, prune_A2, H, layer):
        print('enc2 = ',H)
        H = tf.matmul(H, self.W2[layer])
        if layer == self.n_layers2 - 1:
            return H
        self.C2[layer] = self.graph_attention_layer(A, H, self.v2[layer], layer)
        if self.alpha == 0:
            return tf.sparse.sparse_dense_matmul(self.C2[layer], H)
        else:
            self.prune_C2[layer] = self.graph_attention_layer(prune_A2, H, self.prune_v2[layer], layer)
            return (1 - self.alpha) * tf.sparse.sparse_dense_matmul(self.C2[layer], H) + self.alpha * tf.sparse.sparse_dense_matmul(
                self.prune_C2[layer], H)
    
    def __decoder1(self, H, layer):
        print('dec1 = ',H)
        H = tf.matmul(H, self.W1[layer], transpose_b=True)
        if layer == 0:

            return H
        if self.alpha == 0:

            return tf.sparse.sparse_dense_matmul(self.C1[layer-1], H)
        else:

            return (1 - self.alpha) * tf.sparse.sparse_dense_matmul(self.C1[layer-1], H) + self.alpha * tf.sparse.sparse_dense_matmul(
                self.prune_C1[layer-1], H)
        
    def __decoder2(self, H, layer):
        print('dec2 = ',H)
        H = tf.matmul(H, self.W2[layer], transpose_b=True)
        if layer == 0:

            return H
        if self.alpha == 0:
            return tf.sparse.sparse_dense_matmul(self.C2[layer-1], H)
        
        else:

            return (1 - self.alpha) * tf.sparse.sparse_dense_matmul(self.C2[layer-1], H) + self.alpha * tf.sparse.sparse_dense_matmul(
                self.prune_C2[layer-1], H)
        

    def __encoder3(self, H):
        print('enc3 = ',H)
        H = tf.keras.layers.Dense(self.z_dim)(H)
        print('LATENT = ',H)
        return H


    

    def define_weights1(self,hidden_dims,n_layers):
        W = {}
        #print('TOTAL LEYRS = ',n_layers)
        #n_layers=len(n_layers)-1
        print('n_layers gene = ',n_layers)
        print('Hidden dim gene = ',hidden_dims)

        for i in range(n_layers):
            W[i] = v1.get_variable("W%s" % i, shape=(hidden_dims[i], hidden_dims[i+1]))

        Ws_att = {}
        for i in range(n_layers-1):
            V= {}
            V[0] = v1.get_variable("V%s_0" % i, shape=(hidden_dims[i+1], 1))
            V[1] = v1.get_variable("V%s_1" % i, shape=(hidden_dims[i+1], 1))

            Ws_att[i] = V
        if self.alpha == 0:
            return W, Ws_att, None
        prune_Ws_att = {}
        for i in range(n_layers-1):
            prune_V = {}
            prune_V[0] = v1.get_variable("prune_V%s_0" % i, shape=(hidden_dims[i+1], 1))
            prune_V[1] = v1.get_variable("prune_V%s_1" % i, shape=(hidden_dims[i+1], 1))

            prune_Ws_att[i] = prune_V

        return W, Ws_att, prune_Ws_att
    
    def define_weights2(self,hidden_dims,n_layers):
        w = {}
        #print('TOTAL LEYRS = ',n_layers)
        #n_layers=len(n_layers)-1
        print('n_layers protein = ',n_layers)
        print('Hidden dim protein = ',hidden_dims)

        for i in range(n_layers):
            w[i] = v1.get_variable("w%s" % i, shape=(hidden_dims[i], hidden_dims[i+1]))

        ws_att = {}
        for i in range(n_layers-1):
            v = {}
            v[0] = v1.get_variable("v%s_0" % i, shape=(hidden_dims[i+1], 1))
            v[1] = v1.get_variable("v%s_1" % i, shape=(hidden_dims[i+1], 1))

            ws_att[i] = v
        if self.alpha == 0:
            return w, ws_att, None
        prune_ws_att = {}
        for i in range(n_layers-1):
            prune_v = {}
            prune_v[0] = v1.get_variable("prune_v%s_0" % i, shape=(hidden_dims[i+1], 1))
            prune_v[1] = v1.get_variable("prune_v%s_1" % i, shape=(hidden_dims[i+1], 1))

            prune_ws_att[i] = prune_v

        return w, ws_att, prune_ws_att
    


    def graph_attention_layer(self, A, M, v, layer):

        with v1.variable_scope("layer_%s" % layer):
            f1 = tf.matmul(M, v[0])
            f1 = A * f1
            f2 = tf.matmul(M, v[1])
            f2 = A * tf.transpose(f2, [1, 0])
            logits = v1.sparse_add(f1, f2)

            unnormalized_attentions = tf.SparseTensor(indices=logits.indices,
                                         values=tf.nn.sigmoid(logits.values),
                                         dense_shape=logits.dense_shape)
            attentions = v1.sparse_softmax(unnormalized_attentions)

            attentions = tf.SparseTensor(indices=attentions.indices,
                                         values=attentions.values,
                                         dense_shape=attentions.dense_shape)

            return attentions

# %%
import tensorflow as tf
import scipy.sparse as sp
import numpy as np
#from .model import GATE
import tensorflow.compat.v1 as v1
from tqdm import tqdm

class STAGATE():

    def __init__(self, hidden_dims1, hidden_dims2,z_dim=30, a=0, alpha=0, n_epochs=500, lr=0.0001, 
                 gradient_clipping=5, nonlinear=True, weight_decay=0.0001, 
                 verbose=True, random_seed=2020,
                 ):
        
        np.random.seed(random_seed)
        tf.random.set_seed(random_seed)
        self.loss_list = []
        self.lr = lr
        self.n_epochs = n_epochs
        self.gradient_clipping = gradient_clipping
        self.build_placeholders()
        self.verbose = verbose
        self.alpha = alpha
        self.a=a
        global C
           

        self.gate = GATE(hidden_dims1,hidden_dims2,z_dim,a,alpha, nonlinear, weight_decay)
        self.c_loss, self.loss, self.H, self.C, self.ReX1, self.ReX2 = self.gate(self.A1,self.A2, self.prune_A1,self.prune_A2, self.X1,self.X2)
        #print(self.loss, self.H, self.C, self.ReX1, self.ReX2,sep='\n')

        self.optimize(self.loss)
        self.build_session()

    def build_placeholders(self):
        self.A1 = v1.sparse_placeholder(dtype=tf.float32)
        self.A2 = v1.sparse_placeholder(dtype=tf.float32)
        self.prune_A1 = v1.sparse_placeholder(dtype=tf.float32)
        self.prune_A2 = v1.sparse_placeholder(dtype=tf.float32)
        self.X1 = v1.placeholder(dtype=tf.float32)
        self.X2 = v1.placeholder(dtype=tf.float32)


    def build_session(self, gpu= True):
        config = v1.ConfigProto()
        config.gpu_options.allow_growth = True
        if gpu == False:
            config.intra_op_parallelism_threads = 0
            config.inter_op_parallelism_threads = 0
        self.session = v1.Session(config=config)
        self.session.run([v1.global_variables_initializer(), v1.local_variables_initializer()])

    def optimize(self, loss):
        optimizer = v1.train.AdamOptimizer(learning_rate=self.lr)
        gradients, variables = zip(*optimizer.compute_gradients(loss))
        gradients, _ = tf.clip_by_global_norm(gradients, self.gradient_clipping)
        self.train_op = optimizer.apply_gradients(zip(gradients, variables))

    def __call__(self, A1, A2, prune_A1,prune_A2, X1, X2):
        for epoch in range(self.n_epochs):
            self.run_epoch(epoch, A1, A2, prune_A1,prune_A2, X1, X2)




    def run_epoch(self, epoch, A1,A2 ,prune_A1,prune_A2, X1,X2):

        c_loss, loss, _ = self.session.run([self.c_loss, self.loss, self.train_op],
                           feed_dict={self.A1: A1,
                                      self.A2: A2,
                                      self.prune_A1: prune_A1,
                                      self.prune_A2: prune_A2,
                                      self.X1: X1,
                                      self.X2: X2})

        self.loss_list.append(loss)
        if self.verbose:
            print("Epoch: %s, Contrastive Loss: %.4f, Loss: %.4f" % (epoch, c_loss,loss))
            
        return loss

    def infer(self, A1,A2, prune_A1,prune_A2, X1,X2):
        global C
        H, C, ReX1, ReX2 = self.session.run([self.H, self.C, self.ReX1, self.ReX2],
                                    feed_dict={self.A1: A1,
                                               self.A2: A2,
                                               self.prune_A1: prune_A1,
                                               self.prune_A2: prune_A2,
                                               self.X1: X1,
                                               self.X2: X2})


        return H, self.Conbine_Atten_1(C),self.Conbine_Atten_1(C), self.loss_list, ReX1,ReX2

    #Gene
    def Conbine_Atten_1(self, input):
       
        if self.alpha == 0:
            return [sp.coo_matrix((input[layer][1], (input[layer][0][:, 0], input[layer][0][:, 1])), shape=(input[layer][2][0], input[layer][2][1])) for layer in input]
        else:
            
            Att_C = [sp.coo_matrix((input['C1'][layer][1], (input['C1'][layer][0][:, 0], input['C1'][layer][0][:, 1])), shape=(input['C1'][layer][2][0], input['C1'][layer][2][1])) for layer in input['C1']]
            Att_pruneC = [sp.coo_matrix((input['prune_C1'][layer][1], (input['prune_C1'][layer][0][:, 0], input['prune_C1'][layer][0][:, 1])), shape=(input['prune_C1'][layer][2][0], input['prune_C1'][layer][2][1])) for layer in input['prune_C1']]
            return [self.alpha*Att_pruneC[layer] + (1-self.alpha)*Att_C[layer] for layer in input['C1']]

    #Protein
    def Conbine_Atten_2(self, input):
       
        if self.alpha == 0:
            return [sp.coo_matrix((input[layer][1], (input[layer][0][:, 0], input[layer][0][:, 1])), shape=(input[layer][2][0], input[layer][2][1])) for layer in input]
        else:
            
            Att_C = [sp.coo_matrix((input['C2'][layer][1], (input['C2'][layer][0][:, 0], input['C2'][layer][0][:, 1])), shape=(input['C2'][layer][2][0], input['C2'][layer][2][1])) for layer in input['C2']]
            Att_pruneC = [sp.coo_matrix((input['prune_C2'][layer][1], (input['prune_C2'][layer][0][:, 0], input['prune_C2'][layer][0][:, 1])), shape=(input['prune_C2'][layer][2][0], input['prune_C2'][layer][2][1])) for layer in input['prune_C2']]
            return [self.alpha*Att_pruneC[layer] + (1-self.alpha)*Att_C[layer] for layer in input['C2']]

# %%
# For the Stereo-Seq Data

import numpy as np
import scipy.sparse as sp
#from .STAGATE import STAGATE
import tensorflow as tf
import pandas as pd
import scanpy as sc

def train_STAGATE(adata1,adata2, 
                hidden_dims1=[512, 30],hidden_dims2=[512, 30],z_dim=30, a=0, alpha=0, n_epochs=500, lr=0.0001, key_added='MY_ARCH',
                gradient_clipping=5, nonlinear=True, weight_decay=0.0001,verbose=True, 
                random_seed=2020, pre_labels=None, pre_resolution1=0.2, pre_resolution2=0.2,
                save_attention=False, save_loss=False, save_reconstrction=False
                ):
    """\
    Training graph attention auto-encoder.

    Parameters
    ----------
    adata
        AnnData object of scanpy package.
    hidden_dims
        The dimension of the encoder.
    alpha
        The weight of cell type-aware spatial neighbor network.
    n_epochs
        Number of total epochs in training.
    lr
        Learning rate for AdamOptimizer.
    key_added
        The latent embeddings are saved in adata.obsm[key_added].
    gradient_clipping
        Gradient Clipping.
    nonlinear
        If True, the nonlinear avtivation is performed.
    weight_decay
        Weight decay for AdamOptimizer.
    pre_labels
        The key in adata.obs for the manually designate the pre-clustering results. Only used when alpha>0.
    pre_resolution
        The resolution parameter of sc.tl.louvain for the pre-clustering. Only used when alpha>0 and per_labels==None.
    save_attention
        If True, the weights of the attention layers are saved in adata.uns['STAGATE_attention']
    save_loss
        If True, the training loss is saved in adata.uns['STAGATE_loss'].
    save_reconstrction
        If True, the reconstructed expression profiles are saved in adata.layers['STAGATE_ReX'].

    Returns
    -------
    AnnData
    """

    #tf.reset_default_graph()
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)

    if 'highly_variable' in adata1.var.columns:
        adata_Vars1 =  adata1[:, adata1.var['highly_variable']]
    else:
        adata_Vars1 = adata1
    X1 = pd.DataFrame(adata_Vars1.X[:, ].toarray(), index=adata_Vars1.obs.index, columns=adata_Vars1.var.index)

    
    if 'highly_variable' in adata2.var.columns:
        adata_Vars2 =  adata2[:, adata2.var['highly_variable']]
    else:
        adata_Vars2 = adata2
    X2 = pd.DataFrame(adata_Vars2.X[:, ].toarray(), index=adata_Vars2.obs.index, columns=adata_Vars2.var.index)

    if verbose:
        print('Size of Input for gene data : ', adata_Vars1.shape)
        print('Size of Input for protein data : ',adata_Vars2.shape)


    cells1 = np.array(X1.index)
    cells_id_tran1 = dict(zip(cells1, range(cells1.shape[0])))
    if 'Spatial_Net' not in adata1.uns.keys():
        raise ValueError("Spatial_Net is not existed for gene Run Cal_Spatial_Net first!")

    Spatial_Net1 = adata1.uns['Spatial_Net']
    G_df1 = Spatial_Net1.copy()
    G_df1['Cell1'] = G_df1['Cell1'].map(cells_id_tran1)
    G_df1['Cell2'] = G_df1['Cell2'].map(cells_id_tran1)
    G1 = sp.coo_matrix((np.ones(G_df1.shape[0]), (G_df1['Cell1'], G_df1['Cell2'])), shape=(adata1.n_obs, adata1.n_obs))
    global G_tf1
    G_tf1 = prepare_graph_data(G1)


    cells2 = np.array(X2.index)
    cells_id_tran2 = dict(zip(cells2, range(cells2.shape[0])))
    if 'Spatial_Net' not in adata2.uns.keys():
        raise ValueError("Spatial_Net is not existed for protein Run Cal_Spatial_Net first!")
    Spatial_Net2 = adata1.uns['Spatial_Net']
    G_df2 = Spatial_Net2.copy()
    G_df2['Cell1'] = G_df2['Cell1'].map(cells_id_tran2)
    G_df2['Cell2'] = G_df2['Cell2'].map(cells_id_tran2)
    G2 = sp.coo_matrix((np.ones(G_df2.shape[0]), (G_df2['Cell1'], G_df2['Cell2'])), shape=(adata2.n_obs, adata2.n_obs))
    global G_tf2
    G_tf2 = prepare_graph_data(G2)


    tf.compat.v1.disable_eager_execution()
    trainer = STAGATE(hidden_dims1=[X1.shape[1]] + hidden_dims1,hidden_dims2=[X2.shape[1]] + hidden_dims2, z_dim=z_dim,a=a,alpha=alpha, 
                    n_epochs=n_epochs, lr=lr, gradient_clipping=gradient_clipping, 
                    nonlinear=nonlinear,weight_decay=weight_decay, verbose=verbose, 
                    random_seed=random_seed                    
                    )
    

    print("START TRAIN")
    
    
    if alpha == 0:
        trainer(G_tf1, G_tf2, G_tf1, X1,X2)
        embeddings, attentions, loss, ReX1, ReX2= trainer.infer(G_tf1, G_tf2, G_tf1, X1,X2)
    else:
        G_df1 = Spatial_Net1.copy()
        G_df2 = Spatial_Net1.copy()
        if pre_labels==None:
            if verbose:
                print('------Pre-clustering Genes using louvain with resolution=%.2f' %pre_resolution1)
            sc.tl.pca(adata1, svd_solver='arpack')
            sc.pp.neighbors(adata1)
            sc.tl.louvain(adata1, resolution=pre_resolution1, key_added='expression_louvain_label1')
            pre_labels1 = 'expression_louvain_label1'

            if verbose:
                print('------Pre-clustering Protein using louvain with resolution=%.2f' %pre_resolution2)
            sc.tl.pca(adata2, svd_solver='arpack')
            sc.pp.neighbors(adata2)
            sc.tl.louvain(adata2, resolution=pre_resolution2, key_added='expression_louvain_label2')
            pre_labels2 = 'expression_louvain_label2'

        prune_G_df1 = prune_spatial_Net(G_df1, adata1.obs[pre_labels1])
        prune_G_df2 = prune_spatial_Net(G_df2, adata2.obs[pre_labels2])

        prune_G_df1['Cell1'] = prune_G_df1['Cell1'].map(cells_id_tran1)
        prune_G_df2['Cell1'] = prune_G_df2['Cell1'].map(cells_id_tran2)

        prune_G_df1['Cell2'] = prune_G_df1['Cell2'].map(cells_id_tran1)
        prune_G_df2['Cell2'] = prune_G_df2['Cell2'].map(cells_id_tran2)

        prune_G1 = sp.coo_matrix((np.ones(prune_G_df1.shape[0]), (prune_G_df1['Cell1'], prune_G_df1['Cell2'])))
        prune_G2 = sp.coo_matrix((np.ones(prune_G_df2.shape[0]), (prune_G_df2['Cell1'], prune_G_df2['Cell2'])))
        
        prune_G_tf1 = prepare_graph_data(prune_G1)
        prune_G_tf2 = prepare_graph_data(prune_G2)

        prune_G_tf1 = (prune_G_tf1[0], prune_G_tf1[1], G_tf1[2])
        prune_G_tf2 = (prune_G_tf2[0], prune_G_tf2[1], G_tf2[2])

        # pre-clustering result genes
        plt.rcParams["figure.figsize"] = (5, 5)
        sc.pl.spatial(gdata, img_key="hires", color="expression_louvain_label1", size=1.5, title='gene pre-clustering result', spot_size=100)

        # pre-clustering result protein 
        plt.rcParams["figure.figsize"] = (5, 5)
        sc.pl.spatial(pdata, img_key="hires", color="expression_louvain_label2", size=1.5, title='protein pre-clustering result', spot_size=100)


        trainer(G_tf1,G_tf2, prune_G_tf1,prune_G_tf2, X1,X2)
        embeddings, attention1 , attention2 , loss, ReX1, ReX2 = trainer.infer(G_tf1,G_tf2, prune_G_tf1,prune_G_tf2, X1,X2)

    global df
    cell_reps = pd.DataFrame(embeddings)
    df=cell_reps
    cell_reps.index = cells1

    adata1.obsm[key_added] = cell_reps.loc[adata1.obs_names, ].values
    if save_attention:
        adata1.uns['gene_attention'] = attention1
        adata1.uns['protein_attention'] = attention2

    if save_loss:
        adata1.uns['arch_loss'] = loss
        
    if save_reconstrction:
        ReX1 = pd.DataFrame(ReX1, index=X1.index, columns=X1.columns)
        ReX1[ReX1<0] = 0
        adata1.layers['arch_ReX1'] = ReX1.values
        ReX2 = pd.DataFrame(ReX2, index=X2.index, columns=X2.columns)
        ReX2[ReX2<0] = 0
        adata2.layers['arch_ReX2'] = ReX2.values

    return adata1




def prune_spatial_Net(Graph_df, label):
    print('------Pruning the graph...')
    print('%d edges before pruning.' %Graph_df.shape[0])
    pro_labels_dict = dict(zip(list(label.index), label))
    Graph_df['Cell1_label'] = Graph_df['Cell1'].map(pro_labels_dict)
    Graph_df['Cell2_label'] = Graph_df['Cell2'].map(pro_labels_dict)
    Graph_df = Graph_df.loc[Graph_df['Cell1_label']==Graph_df['Cell2_label'],]
    print('%d edges after pruning.' %Graph_df.shape[0])
    return Graph_df


def prepare_graph_data(adj):
    # adapted from preprocess_adj_bias
    num_nodes = adj.shape[0]
    adj = adj + sp.eye(num_nodes)# self-loop
    #data =  adj.tocoo().data
    #adj[adj > 0.0] = 1.0
    if not sp.isspmatrix_coo(adj):
        adj = adj.tocoo()
    adj = adj.astype(np.float32)
    indices = np.vstack((adj.col, adj.row)).transpose()
    return (indices, adj.data, adj.shape)

def recovery_Imputed_Count(adata, size_factor):
    assert('ReX1' in adata.uns)
    temp_df = adata.uns['ReX1'].copy()
    sf = size_factor.loc[temp_df.index]
    temp_df = np.expm1(temp_df)
    temp_df = (temp_df.T * sf).T
    adata.uns['ReX_Count1'] = temp_df
    
    assert('ReX2' in adata.uns)
    temp_df = adata.uns['ReX2'].copy()
    sf = size_factor.loc[temp_df.index]
    temp_df = np.expm1(temp_df)
    temp_df = (temp_df.T * sf).T
    adata.uns['ReX_Count2'] = temp_df

    return adata

# %%
# # For the Landau Data

# import numpy as np
# import scipy.sparse as sp
# #from .STAGATE import STAGATE
# import tensorflow as tf
# import pandas as pd
# import scanpy as sc

# def train_STAGATE(adata1,adata2, 
#                 hidden_dims1=[512, 30],hidden_dims2=[512, 30],z_dim=30, a=0, alpha=0, n_epochs=500, lr=0.0001, key_added='MY_ARCH',
#                 gradient_clipping=5, nonlinear=True, weight_decay=0.0001,verbose=True, 
#                 random_seed=2020, pre_labels=None, pre_resolution1=0.2, pre_resolution2=0.2,
#                 save_attention=False, save_loss=False, save_reconstrction=False
#                 ):
#     """\
#     Training graph attention auto-encoder.

#     Parameters
#     ----------
#     adata
#         AnnData object of scanpy package.
#     hidden_dims
#         The dimension of the encoder.
#     alpha
#         The weight of cell type-aware spatial neighbor network.
#     n_epochs
#         Number of total epochs in training.
#     lr
#         Learning rate for AdamOptimizer.
#     key_added
#         The latent embeddings are saved in adata.obsm[key_added].
#     gradient_clipping
#         Gradient Clipping.
#     nonlinear
#         If True, the nonlinear avtivation is performed.
#     weight_decay
#         Weight decay for AdamOptimizer.
#     pre_labels
#         The key in adata.obs for the manually designate the pre-clustering results. Only used when alpha>0.
#     pre_resolution
#         The resolution parameter of sc.tl.louvain for the pre-clustering. Only used when alpha>0 and per_labels==None.
#     save_attention
#         If True, the weights of the attention layers are saved in adata.uns['STAGATE_attention']
#     save_loss
#         If True, the training loss is saved in adata.uns['STAGATE_loss'].
#     save_reconstrction
#         If True, the reconstructed expression profiles are saved in adata.layers['STAGATE_ReX'].

#     Returns
#     -------
#     AnnData
#     """

#     #tf.reset_default_graph()
#     np.random.seed(random_seed)
#     tf.random.set_seed(random_seed)

#     if 'highly_variable' in adata1.var.columns:
#         adata_Vars1 =  adata1[:, adata1.var['highly_variable']]
#     else:
#         adata_Vars1 = adata1
#     X1 = pd.DataFrame(adata_Vars1.X[:, ].toarray(), index=adata_Vars1.obs.index, columns=adata_Vars1.var.index)

    
#     if 'highly_variable' in adata2.var.columns:
#         adata_Vars2 =  adata2[:, adata2.var['highly_variable']]
#     else:
#         adata_Vars2 = adata2
#     X2 = pd.DataFrame(adata_Vars2.X[:, ], index=adata_Vars2.obs.index, columns=adata_Vars2.var.index)

#     if verbose:
#         print('Size of Input for gene data : ', adata_Vars1.shape)
#         print('Size of Input for protein data : ',adata_Vars2.shape)



#     cells1 = np.array(X1.index)
#     cells_id_tran1 = dict(zip(cells1, range(cells1.shape[0])))
#     if 'Spatial_Net' not in adata1.uns.keys():
#         raise ValueError("Spatial_Net is not existed for gene Run Cal_Spatial_Net first!")

#     Spatial_Net1 = adata1.uns['Spatial_Net']
#     G_df1 = Spatial_Net1.copy()
#     G_df1['Cell1'] = G_df1['Cell1'].map(cells_id_tran1)
#     G_df1['Cell2'] = G_df1['Cell2'].map(cells_id_tran1)
#     G1 = sp.coo_matrix((np.ones(G_df1.shape[0]), (G_df1['Cell1'], G_df1['Cell2'])), shape=(adata1.n_obs, adata1.n_obs))
#     global G_tf1
#     G_tf1 = prepare_graph_data(G1)


#     cells2 = np.array(X2.index)
#     cells_id_tran2 = dict(zip(cells2, range(cells2.shape[0])))
#     if 'Spatial_Net' not in adata2.uns.keys():
#         raise ValueError("Spatial_Net is not existed for protein Run Cal_Spatial_Net first!")
#     Spatial_Net2 = adata1.uns['Spatial_Net']
#     G_df2 = Spatial_Net2.copy()
#     G_df2['Cell1'] = G_df2['Cell1'].map(cells_id_tran2)
#     G_df2['Cell2'] = G_df2['Cell2'].map(cells_id_tran2)
#     G2 = sp.coo_matrix((np.ones(G_df2.shape[0]), (G_df2['Cell1'], G_df2['Cell2'])), shape=(adata2.n_obs, adata2.n_obs))
#     global G_tf2
#     G_tf2 = prepare_graph_data(G2)


#     tf.compat.v1.disable_eager_execution()
#     trainer = STAGATE(hidden_dims1=[X1.shape[1]] + hidden_dims1,hidden_dims2=[X2.shape[1]] + hidden_dims2, z_dim=z_dim,a=a,alpha=alpha, 
#                     n_epochs=n_epochs, lr=lr, gradient_clipping=gradient_clipping, 
#                     nonlinear=nonlinear,weight_decay=weight_decay, verbose=verbose, 
#                     random_seed=random_seed                    
#                     )
    

#     print("START TRAIN")
    
    
#     if alpha == 0:
#         trainer(G_tf1, G_tf2, G_tf1, X1,X2)
#         embeddings, attentions, loss, ReX1, ReX2= trainer.infer(G_tf1, G_tf2, G_tf1, X1,X2)
#     else:
#         G_df1 = Spatial_Net1.copy()
#         G_df2 = Spatial_Net1.copy()
#         if pre_labels==None:
#             if verbose:
#                 print('------Pre-clustering Genes using louvain with resolution=%.2f' %pre_resolution1)
#             sc.tl.pca(adata1, svd_solver='arpack')
#             sc.pp.neighbors(adata1)
#             sc.tl.louvain(adata1, resolution=pre_resolution1, key_added='expression_louvain_label1')
#             pre_labels1 = 'expression_louvain_label1'

#             if verbose:
#                 print('------Pre-clustering Protein using louvain with resolution=%.2f' %pre_resolution2)
#             sc.tl.pca(adata2, svd_solver='arpack')
#             sc.pp.neighbors(adata2)
#             sc.tl.louvain(adata2, resolution=pre_resolution2, key_added='expression_louvain_label2')
#             pre_labels2 = 'expression_louvain_label2'

#         prune_G_df1 = prune_spatial_Net(G_df1, adata1.obs[pre_labels1])
#         prune_G_df2 = prune_spatial_Net(G_df2, adata2.obs[pre_labels2])

#         prune_G_df1['Cell1'] = prune_G_df1['Cell1'].map(cells_id_tran1)
#         prune_G_df2['Cell1'] = prune_G_df2['Cell1'].map(cells_id_tran2)

#         prune_G_df1['Cell2'] = prune_G_df1['Cell2'].map(cells_id_tran1)
#         prune_G_df2['Cell2'] = prune_G_df2['Cell2'].map(cells_id_tran2)

#         prune_G1 = sp.coo_matrix((np.ones(prune_G_df1.shape[0]), (prune_G_df1['Cell1'], prune_G_df1['Cell2'])))
#         prune_G2 = sp.coo_matrix((np.ones(prune_G_df2.shape[0]), (prune_G_df2['Cell1'], prune_G_df2['Cell2'])))
        
#         prune_G_tf1 = prepare_graph_data(prune_G1)
#         prune_G_tf2 = prepare_graph_data(prune_G2)

#         prune_G_tf1 = (prune_G_tf1[0], prune_G_tf1[1], G_tf1[2])
#         prune_G_tf2 = (prune_G_tf2[0], prune_G_tf2[1], G_tf2[2])

#         # pre-clustering result genes
#         plt.rcParams["figure.figsize"] = (5, 5)
#         sc.pl.spatial(gdata, img_key="hires", color="expression_louvain_label1", size=1.5, title='gene pre-clustering result')

#         # pre-clustering result protein 
#         plt.rcParams["figure.figsize"] = (5, 5)
#         sc.pl.spatial(pdata, img_key="hires", color="expression_louvain_label2", size=1.5, title='protein pre-clustering result')


#         trainer(G_tf1,G_tf2, prune_G_tf1,prune_G_tf2, X1,X2)
#         embeddings, attention1 , attention2 , loss, ReX1, ReX2 = trainer.infer(G_tf1,G_tf2, prune_G_tf1,prune_G_tf2, X1,X2)

#     global df
#     cell_reps = pd.DataFrame(embeddings)
#     df=cell_reps
#     cell_reps.index = cells1

#     adata1.obsm[key_added] = cell_reps.loc[adata1.obs_names, ].values
#     if save_attention:
#         adata1.uns['gene_attention'] = attention1
#         adata1.uns['protein_attention'] = attention2

#     if save_loss:
#         adata1.uns['arch_loss'] = loss
        
#     if save_reconstrction:
#         ReX1 = pd.DataFrame(ReX1, index=X1.index, columns=X1.columns)
#         ReX1[ReX1<0] = 0
#         adata1.layers['arch_ReX1'] = ReX1.values
#         ReX2 = pd.DataFrame(ReX2, index=X2.index, columns=X2.columns)
#         ReX2[ReX2<0] = 0
#         adata2.layers['arch_ReX2'] = ReX2.values

#     return adata1




# def prune_spatial_Net(Graph_df, label):
#     print('------Pruning the graph...')
#     print('%d edges before pruning.' %Graph_df.shape[0])
#     pro_labels_dict = dict(zip(list(label.index), label))
#     Graph_df['Cell1_label'] = Graph_df['Cell1'].map(pro_labels_dict)
#     Graph_df['Cell2_label'] = Graph_df['Cell2'].map(pro_labels_dict)
#     Graph_df = Graph_df.loc[Graph_df['Cell1_label']==Graph_df['Cell2_label'],]
#     print('%d edges after pruning.' %Graph_df.shape[0])
#     return Graph_df


# def prepare_graph_data(adj):
#     # adapted from preprocess_adj_bias
#     num_nodes = adj.shape[0]
#     adj = adj + sp.eye(num_nodes)# self-loop
#     #data =  adj.tocoo().data
#     #adj[adj > 0.0] = 1.0
#     if not sp.isspmatrix_coo(adj):
#         adj = adj.tocoo()
#     adj = adj.astype(np.float32)
#     indices = np.vstack((adj.col, adj.row)).transpose()
#     return (indices, adj.data, adj.shape)

# def recovery_Imputed_Count(adata, size_factor):
#     assert('ReX1' in adata.uns)
#     temp_df = adata.uns['ReX1'].copy()
#     sf = size_factor.loc[temp_df.index]
#     temp_df = np.expm1(temp_df)
#     temp_df = (temp_df.T * sf).T
#     adata.uns['ReX_Count1'] = temp_df
    
#     assert('ReX2' in adata.uns)
#     temp_df = adata.uns['ReX2'].copy()
#     sf = size_factor.loc[temp_df.index]
#     temp_df = np.expm1(temp_df)
#     temp_df = (temp_df.T * sf).T
#     adata.uns['ReX_Count2'] = temp_df

#     return adata

# %%
import pandas as pd
import numpy as np
import sklearn.neighbors


def Cal_Spatial_Net(adata, rad_cutoff=None, k_cutoff=None, model='Radius', verbose=True):
    """\
    Construct the spatial neighbor networks.

    Parameters
    ----------
    adata
        AnnData object of scanpy package.
    rad_cutoff
        radius cutoff when model='Radius'
    k_cutoff
        The number of nearest neighbors when model='KNN'
    model
        The network construction model. When model=='Radius', the spot is connected to spots whose distance is less than rad_cutoff. When model=='KNN', the spot is connected to its first k_cutoff nearest neighbors.
    
    Returns
    -------
    The spatial networks are saved in adata.uns['Spatial_Net']
    """

    assert(model in ['Radius', 'KNN'])
    if verbose:
        print('------Calculating spatial graph...')
    coor = pd.DataFrame(adata.obsm['spatial'])
    coor.index = adata.obs.index
    coor.columns = ['imagerow', 'imagecol']

    if model == 'Radius':
        nbrs = sklearn.neighbors.NearestNeighbors(radius=rad_cutoff).fit(coor)
        distances, indices = nbrs.radius_neighbors(coor, return_distance=True)
        KNN_list = []
        for it in range(indices.shape[0]):
            KNN_list.append(pd.DataFrame(zip([it]*indices[it].shape[0], indices[it], distances[it])))
    
    if model == 'KNN':
        nbrs = sklearn.neighbors.NearestNeighbors(n_neighbors=k_cutoff+1).fit(coor)
        distances, indices = nbrs.kneighbors(coor)
        KNN_list = []
        for it in range(indices.shape[0]):
            KNN_list.append(pd.DataFrame(zip([it]*indices.shape[1],indices[it,:], distances[it,:])))

    KNN_df = pd.concat(KNN_list)
    KNN_df.columns = ['Cell1', 'Cell2', 'Distance']

    Spatial_Net = KNN_df.copy()
    Spatial_Net = Spatial_Net.loc[Spatial_Net['Distance']>0,]
    id_cell_trans = dict(zip(range(coor.shape[0]), np.array(coor.index), ))
    Spatial_Net['Cell1'] = Spatial_Net['Cell1'].map(id_cell_trans)
    Spatial_Net['Cell2'] = Spatial_Net['Cell2'].map(id_cell_trans)
    if verbose:
        print('The graph contains %d edges, %d cells.' %(Spatial_Net.shape[0], adata.n_obs))
        print('%.4f neighbors per cell on average.' %(Spatial_Net.shape[0]/adata.n_obs))

    adata.uns['Spatial_Net'] = Spatial_Net


def Cal_Spatial_Net_3D(adata, rad_cutoff_2D, rad_cutoff_Zaxis,
                       key_section='Section_id', section_order=None, verbose=True):
    """\
    Construct the spatial neighbor networks.

    Parameters
    ----------
    adata
        AnnData object of scanpy package.
    rad_cutoff_2D
        radius cutoff for 2D SNN construction.
    rad_cutoff_Zaxis
        radius cutoff for 2D SNN construction for consturcting SNNs between adjacent sections.
    key_section
        The columns names of section_ID in adata.obs.
    section_order
        The order of sections. The SNNs between adjacent sections are constructed according to this order.
    
    Returns
    -------
    The 3D spatial networks are saved in adata.uns['Spatial_Net'].
    """
    adata.uns['Spatial_Net_2D'] = pd.DataFrame()
    adata.uns['Spatial_Net_Zaxis'] = pd.DataFrame()
    num_section = np.unique(adata.obs[key_section]).shape[0]
    if verbose:
        print('Radius used for 2D SNN:', rad_cutoff_2D)
        print('Radius used for SNN between sections:', rad_cutoff_Zaxis)
    for temp_section in np.unique(adata.obs[key_section]):
        if verbose:
            print('------Calculating 2D SNN of section ', temp_section)
        temp_adata = adata[adata.obs[key_section] == temp_section, ]
        Cal_Spatial_Net(
            temp_adata, rad_cutoff=rad_cutoff_2D, verbose=False)
        temp_adata.uns['Spatial_Net']['SNN'] = temp_section
        if verbose:
            print('This graph contains %d edges, %d cells.' %
                  (temp_adata.uns['Spatial_Net'].shape[0], temp_adata.n_obs))
            print('%.4f neighbors per cell on average.' %
                  (temp_adata.uns['Spatial_Net'].shape[0]/temp_adata.n_obs))
        adata.uns['Spatial_Net_2D'] = pd.concat(
            [adata.uns['Spatial_Net_2D'], temp_adata.uns['Spatial_Net']])
    for it in range(num_section-1):
        section_1 = section_order[it]
        section_2 = section_order[it+1]
        if verbose:
            print('------Calculating SNN between adjacent section %s and %s.' %
                  (section_1, section_2))
        Z_Net_ID = section_1+'-'+section_2
        temp_adata = adata[adata.obs[key_section].isin(
            [section_1, section_2]), ]
        Cal_Spatial_Net(
            temp_adata, rad_cutoff=rad_cutoff_Zaxis, verbose=False)
        spot_section_trans = dict(
            zip(temp_adata.obs.index, temp_adata.obs[key_section]))
        temp_adata.uns['Spatial_Net']['Section_id_1'] = temp_adata.uns['Spatial_Net']['Cell1'].map(
            spot_section_trans)
        temp_adata.uns['Spatial_Net']['Section_id_2'] = temp_adata.uns['Spatial_Net']['Cell2'].map(
            spot_section_trans)
        used_edge = temp_adata.uns['Spatial_Net'].apply(
            lambda x: x['Section_id_1'] != x['Section_id_2'], axis=1)
        temp_adata.uns['Spatial_Net'] = temp_adata.uns['Spatial_Net'].loc[used_edge, ]
        temp_adata.uns['Spatial_Net'] = temp_adata.uns['Spatial_Net'].loc[:, [
            'Cell1', 'Cell2', 'Distance']]
        temp_adata.uns['Spatial_Net']['SNN'] = Z_Net_ID
        if verbose:
            print('This graph contains %d edges, %d cells.' %
                  (temp_adata.uns['Spatial_Net'].shape[0], temp_adata.n_obs))
            print('%.4f neighbors per cell on average.' %
                  (temp_adata.uns['Spatial_Net'].shape[0]/temp_adata.n_obs))
        adata.uns['Spatial_Net_Zaxis'] = pd.concat(
            [adata.uns['Spatial_Net_Zaxis'], temp_adata.uns['Spatial_Net']])
    adata.uns['Spatial_Net'] = pd.concat(
        [adata.uns['Spatial_Net_2D'], adata.uns['Spatial_Net_Zaxis']])
    if verbose:
        print('3D SNN contains %d edges, %d cells.' %
            (adata.uns['Spatial_Net'].shape[0], adata.n_obs))
        print('%.4f neighbors per cell on average.' %
            (adata.uns['Spatial_Net'].shape[0]/adata.n_obs))

def Stats_Spatial_Net(adata):
    import matplotlib.pyplot as plt
    Num_edge = adata.uns['Spatial_Net']['Cell1'].shape[0]
    Mean_edge = Num_edge/adata.shape[0]
    plot_df = pd.value_counts(pd.value_counts(adata.uns['Spatial_Net']['Cell1']))
    plot_df = plot_df/adata.shape[0]
    fig, ax = plt.subplots(figsize=[3,2])
    plt.ylabel('Percentage')
    plt.xlabel('')
    plt.title('Number of Neighbors (Mean=%.2f)'%Mean_edge)
    ax.bar(plot_df.index, plot_df)

def mclust_R(adata, num_cluster, modelNames='EEE', used_obsm='STAGATE', random_seed=2020):
    """\
    Clustering using the mclust algorithm.
    The parameters are the same as those in the R package mclust.
    """
    
    np.random.seed(random_seed)
    import rpy2.robjects as robjects
    robjects.r.library("mclust")

    import rpy2.robjects.numpy2ri
    rpy2.robjects.numpy2ri.activate()
    r_random_seed = robjects.r['set.seed']
    r_random_seed(random_seed)
    rmclust = robjects.r['Mclust']

    res = rmclust(rpy2.robjects.numpy2ri.numpy2rpy(adata.obsm[used_obsm]), num_cluster, modelNames)
    mclust_res = np.array(res[-2])

    adata.obs['mclust'] = mclust_res
    adata.obs['mclust'] = adata.obs['mclust'].astype('int')
    adata.obs['mclust'] = adata.obs['mclust'].astype('category')
    return adata

# %%
Cal_Spatial_Net(gdata, rad_cutoff=100)
Stats_Spatial_Net(gdata)
# Out:
# ------Calculating spatial graph...
# The graph contains 18316 edges, 4697 cells.
# 3.8995 neighbors per cell on average.

# %%
Cal_Spatial_Net(pdata, rad_cutoff=100)
Stats_Spatial_Net(pdata)
# Out:
# ------Calculating spatial graph...
# The graph contains 18316 edges, 4697 cells.
# 3.8995 neighbors per cell on average.

# %%
gdata = train_STAGATE(gdata,pdata,n_epochs=500,hidden_dims1=[512,30],hidden_dims2=[128, 30],a=0.05,alpha=0.4,pre_resolution1=0.6,pre_resolution2=0.2, save_loss=True,save_attention=True)
# Out:
# Size of Input for gene data :  (4697, 3000)
# Size of Input for protein data :  (4697, 51)
# n_layers gene =  2
# Hidden dim gene =  [3000, 512, 30]
# n_layers protein =  2
# Hidden dim protein =  [51, 128, 30]
# enc1 =  Tensor("Placeholder_12:0", dtype=float32)
# enc1 =  Tensor("Elu:0", shape=(None, None), dtype=float32)
# enc2 =  Tensor("Placeholder_13:0", dtype=float32)
# enc2 =  Tensor("Elu_1:0", shape=(None, None), dtype=float32)
# enc3 =  Tensor("concat:0", shape=(None, 60), dtype=float32)
# LATENT =  Tensor("dense_4/BiasAdd:0", shape=(None, 30), dtype=float32)
# WARNING:tensorflow:From c:\Users\AGNISH\.conda\envs\STAGATE\lib\site-packages\keras\layers\normalization\batch_normalization.py:581: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# dec1 =  Tensor("add_5:0", shape=(None, 30), dtype=float32)
# dec1 =  Tensor("Elu_2:0", shape=(None, 512), dtype=float32)
# dec2 =  Tensor("add_5:0", shape=(None, 30), dtype=float32)
# dec2 =  Tensor("Elu_3:0", shape=(None, 128), dtype=float32)
# START TRAIN
# ------Pre-clustering Genes using louvain with resolution=0.60
# ------Pre-clustering Protein using louvain with resolution=0.20
# ------Pruning the graph...
# 18316 edges before pruning.
# 12880 edges after pruning.
# ------Pruning the graph...
# 18316 edges before pruning.
# 10866 edges after pruning.
# Epoch: 0, Contrastive Loss: 10.3273, Loss: 3403.1465
# Epoch: 1, Contrastive Loss: 10.2728, Loss: 3303.3022
# Epoch: 2, Contrastive Loss: 10.2271, Loss: 3217.6677
# Epoch: 3, Contrastive Loss: 10.1866, Loss: 3141.4004
# Epoch: 4, Contrastive Loss: 10.1500, Loss: 3088.9675
# Epoch: 5, Contrastive Loss: 10.1157, Loss: 3032.9973
# Epoch: 6, Contrastive Loss: 10.0807, Loss: 2991.6670
# Epoch: 7, Contrastive Loss: 10.0436, Loss: 2956.7812
# Epoch: 8, Contrastive Loss: 10.0040, Loss: 2927.5688
# Epoch: 9, Contrastive Loss: 9.9615, Loss: 2903.1655
# Epoch: 10, Contrastive Loss: 9.9165, Loss: 2881.5562
# Epoch: 11, Contrastive Loss: 9.8696, Loss: 2864.4216
# Epoch: 12, Contrastive Loss: 9.8223, Loss: 2850.4001
# Epoch: 13, Contrastive Loss: 9.7760, Loss: 2835.6780
# Epoch: 14, Contrastive Loss: 9.7311, Loss: 2822.1414
# Epoch: 15, Contrastive Loss: 9.6882, Loss: 2812.4849
# Epoch: 16, Contrastive Loss: 9.6481, Loss: 2801.8257
# Epoch: 17, Contrastive Loss: 9.6109, Loss: 2790.6411
# Epoch: 18, Contrastive Loss: 9.5766, Loss: 2778.6343
# Epoch: 19, Contrastive Loss: 9.5451, Loss: 2766.9563
# Epoch: 20, Contrastive Loss: 9.5162, Loss: 2754.2664
# Epoch: 21, Contrastive Loss: 9.4898, Loss: 2742.4683
# Epoch: 22, Contrastive Loss: 9.4656, Loss: 2729.2126
# Epoch: 23, Contrastive Loss: 9.4435, Loss: 2717.0786
# Epoch: 24, Contrastive Loss: 9.4233, Loss: 2701.4138
# Epoch: 25, Contrastive Loss: 9.4048, Loss: 2687.0913
# Epoch: 26, Contrastive Loss: 9.3880, Loss: 2672.0935
# Epoch: 27, Contrastive Loss: 9.3727, Loss: 2657.4067
# Epoch: 28, Contrastive Loss: 9.3588, Loss: 2642.5632
# Epoch: 29, Contrastive Loss: 9.3463, Loss: 2626.4070
# Epoch: 30, Contrastive Loss: 9.3350, Loss: 2608.5652
# Epoch: 31, Contrastive Loss: 9.3247, Loss: 2592.0051
# Epoch: 32, Contrastive Loss: 9.3155, Loss: 2575.1040
# Epoch: 33, Contrastive Loss: 9.3072, Loss: 2557.9434
# Epoch: 34, Contrastive Loss: 9.2997, Loss: 2539.1514
# Epoch: 35, Contrastive Loss: 9.2929, Loss: 2521.8040
# Epoch: 36, Contrastive Loss: 9.2867, Loss: 2503.1587
# Epoch: 37, Contrastive Loss: 9.2811, Loss: 2486.6790
# Epoch: 38, Contrastive Loss: 9.2759, Loss: 2466.6096
# Epoch: 39, Contrastive Loss: 9.2712, Loss: 2448.7053
# Epoch: 40, Contrastive Loss: 9.2668, Loss: 2429.0994
# Epoch: 41, Contrastive Loss: 9.2627, Loss: 2410.9565
# Epoch: 42, Contrastive Loss: 9.2590, Loss: 2390.1230
# Epoch: 43, Contrastive Loss: 9.2555, Loss: 2370.2332
# Epoch: 44, Contrastive Loss: 9.2522, Loss: 2348.5566
# Epoch: 45, Contrastive Loss: 9.2491, Loss: 2330.0139
# Epoch: 46, Contrastive Loss: 9.2462, Loss: 2309.5227
# Epoch: 47, Contrastive Loss: 9.2435, Loss: 2288.6101
# Epoch: 48, Contrastive Loss: 9.2409, Loss: 2267.2205
# Epoch: 49, Contrastive Loss: 9.2384, Loss: 2245.7839
# Epoch: 50, Contrastive Loss: 9.2361, Loss: 2225.8804
# Epoch: 51, Contrastive Loss: 9.2339, Loss: 2204.1824
# Epoch: 52, Contrastive Loss: 9.2318, Loss: 2183.5027
# Epoch: 53, Contrastive Loss: 9.2298, Loss: 2162.5352
# Epoch: 54, Contrastive Loss: 9.2279, Loss: 2139.9756
# Epoch: 55, Contrastive Loss: 9.2262, Loss: 2118.6907
# Epoch: 56, Contrastive Loss: 9.2244, Loss: 2097.4910
# Epoch: 57, Contrastive Loss: 9.2228, Loss: 2076.1899
# Epoch: 58, Contrastive Loss: 9.2213, Loss: 2054.5444
# Epoch: 59, Contrastive Loss: 9.2198, Loss: 2032.9606
# Epoch: 60, Contrastive Loss: 9.2183, Loss: 2011.9271
# Epoch: 61, Contrastive Loss: 9.2170, Loss: 1990.3070
# Epoch: 62, Contrastive Loss: 9.2156, Loss: 1968.7394
# Epoch: 63, Contrastive Loss: 9.2143, Loss: 1949.4813
# Epoch: 64, Contrastive Loss: 9.2131, Loss: 1928.9204
# Epoch: 65, Contrastive Loss: 9.2119, Loss: 1908.2756
# Epoch: 66, Contrastive Loss: 9.2107, Loss: 1888.3336
# Epoch: 67, Contrastive Loss: 9.2095, Loss: 1867.3728
# Epoch: 68, Contrastive Loss: 9.2084, Loss: 1848.2311
# Epoch: 69, Contrastive Loss: 9.2073, Loss: 1827.9849
# Epoch: 70, Contrastive Loss: 9.2062, Loss: 1809.6315
# Epoch: 71, Contrastive Loss: 9.2051, Loss: 1789.9203
# Epoch: 72, Contrastive Loss: 9.2040, Loss: 1771.7075
# Epoch: 73, Contrastive Loss: 9.2030, Loss: 1751.9603
# Epoch: 74, Contrastive Loss: 9.2019, Loss: 1735.2914
# Epoch: 75, Contrastive Loss: 9.2009, Loss: 1716.7971
# Epoch: 76, Contrastive Loss: 9.1999, Loss: 1698.6414
# Epoch: 77, Contrastive Loss: 9.1989, Loss: 1680.4104
# Epoch: 78, Contrastive Loss: 9.1979, Loss: 1663.0558
# Epoch: 79, Contrastive Loss: 9.1970, Loss: 1645.9104
# Epoch: 80, Contrastive Loss: 9.1960, Loss: 1627.6233
# Epoch: 81, Contrastive Loss: 9.1951, Loss: 1610.6984
# Epoch: 82, Contrastive Loss: 9.1942, Loss: 1594.8096
# Epoch: 83, Contrastive Loss: 9.1933, Loss: 1577.2198
# Epoch: 84, Contrastive Loss: 9.1924, Loss: 1560.2905
# Epoch: 85, Contrastive Loss: 9.1916, Loss: 1544.7322
# Epoch: 86, Contrastive Loss: 9.1907, Loss: 1528.7177
# Epoch: 87, Contrastive Loss: 9.1899, Loss: 1513.2919
# Epoch: 88, Contrastive Loss: 9.1891, Loss: 1498.4020
# Epoch: 89, Contrastive Loss: 9.1884, Loss: 1483.7798
# Epoch: 90, Contrastive Loss: 9.1876, Loss: 1469.2291
# Epoch: 91, Contrastive Loss: 9.1868, Loss: 1455.3892
# Epoch: 92, Contrastive Loss: 9.1861, Loss: 1442.5029
# Epoch: 93, Contrastive Loss: 9.1853, Loss: 1428.5680
# Epoch: 94, Contrastive Loss: 9.1845, Loss: 1416.6133
# Epoch: 95, Contrastive Loss: 9.1838, Loss: 1405.5984
# Epoch: 96, Contrastive Loss: 9.1830, Loss: 1394.9773
# Epoch: 97, Contrastive Loss: 9.1821, Loss: 1384.1440
# Epoch: 98, Contrastive Loss: 9.1812, Loss: 1376.9749
# Epoch: 99, Contrastive Loss: 9.1803, Loss: 1368.3690
# Epoch: 100, Contrastive Loss: 9.1792, Loss: 1361.4192
# Epoch: 101, Contrastive Loss: 9.1781, Loss: 1355.3060
# Epoch: 102, Contrastive Loss: 9.1769, Loss: 1350.7305
# Epoch: 103, Contrastive Loss: 9.1755, Loss: 1346.7429
# Epoch: 104, Contrastive Loss: 9.1741, Loss: 1343.4805
# Epoch: 105, Contrastive Loss: 9.1726, Loss: 1340.5311
# Epoch: 106, Contrastive Loss: 9.1711, Loss: 1337.4535
# Epoch: 107, Contrastive Loss: 9.1696, Loss: 1335.9742
# Epoch: 108, Contrastive Loss: 9.1681, Loss: 1334.1281
# Epoch: 109, Contrastive Loss: 9.1668, Loss: 1331.8699
# Epoch: 110, Contrastive Loss: 9.1655, Loss: 1330.5206
# Epoch: 111, Contrastive Loss: 9.1643, Loss: 1328.2827
# Epoch: 112, Contrastive Loss: 9.1631, Loss: 1325.7983
# Epoch: 113, Contrastive Loss: 9.1621, Loss: 1323.3143
# Epoch: 114, Contrastive Loss: 9.1611, Loss: 1321.5002
# Epoch: 115, Contrastive Loss: 9.1601, Loss: 1318.9463
# Epoch: 116, Contrastive Loss: 9.1592, Loss: 1316.7405
# Epoch: 117, Contrastive Loss: 9.1584, Loss: 1314.4434
# Epoch: 118, Contrastive Loss: 9.1575, Loss: 1313.2698
# Epoch: 119, Contrastive Loss: 9.1567, Loss: 1311.4803
# Epoch: 120, Contrastive Loss: 9.1559, Loss: 1309.9462
# Epoch: 121, Contrastive Loss: 9.1551, Loss: 1308.8462
# Epoch: 122, Contrastive Loss: 9.1544, Loss: 1307.9851
# Epoch: 123, Contrastive Loss: 9.1537, Loss: 1306.1384
# Epoch: 124, Contrastive Loss: 9.1531, Loss: 1304.6169
# Epoch: 125, Contrastive Loss: 9.1525, Loss: 1303.2787
# Epoch: 126, Contrastive Loss: 9.1520, Loss: 1301.6200
# Epoch: 127, Contrastive Loss: 9.1515, Loss: 1300.3862
# Epoch: 128, Contrastive Loss: 9.1511, Loss: 1299.2324
# Epoch: 129, Contrastive Loss: 9.1507, Loss: 1298.0865
# Epoch: 130, Contrastive Loss: 9.1503, Loss: 1297.2894
# Epoch: 131, Contrastive Loss: 9.1499, Loss: 1295.6268
# Epoch: 132, Contrastive Loss: 9.1496, Loss: 1294.2472
# Epoch: 133, Contrastive Loss: 9.1493, Loss: 1293.2954
# Epoch: 134, Contrastive Loss: 9.1490, Loss: 1292.6028
# Epoch: 135, Contrastive Loss: 9.1488, Loss: 1291.2845
# Epoch: 136, Contrastive Loss: 9.1485, Loss: 1290.6423
# Epoch: 137, Contrastive Loss: 9.1484, Loss: 1288.9332
# Epoch: 138, Contrastive Loss: 9.1482, Loss: 1287.8923
# Epoch: 139, Contrastive Loss: 9.1480, Loss: 1287.4456
# Epoch: 140, Contrastive Loss: 9.1479, Loss: 1286.1462
# Epoch: 141, Contrastive Loss: 9.1478, Loss: 1285.3448
# Epoch: 142, Contrastive Loss: 9.1476, Loss: 1284.3474
# Epoch: 143, Contrastive Loss: 9.1475, Loss: 1283.3290
# Epoch: 144, Contrastive Loss: 9.1475, Loss: 1282.6222
# Epoch: 145, Contrastive Loss: 9.1474, Loss: 1281.5881
# Epoch: 146, Contrastive Loss: 9.1473, Loss: 1280.3536
# Epoch: 147, Contrastive Loss: 9.1472, Loss: 1279.4812
# Epoch: 148, Contrastive Loss: 9.1472, Loss: 1278.5295
# Epoch: 149, Contrastive Loss: 9.1471, Loss: 1277.4929
# Epoch: 150, Contrastive Loss: 9.1470, Loss: 1276.5563
# Epoch: 151, Contrastive Loss: 9.1470, Loss: 1275.8628
# Epoch: 152, Contrastive Loss: 9.1469, Loss: 1275.0394
# Epoch: 153, Contrastive Loss: 9.1469, Loss: 1273.9159
# Epoch: 154, Contrastive Loss: 9.1468, Loss: 1272.9010
# Epoch: 155, Contrastive Loss: 9.1468, Loss: 1272.1749
# Epoch: 156, Contrastive Loss: 9.1468, Loss: 1271.1045
# Epoch: 157, Contrastive Loss: 9.1467, Loss: 1269.8531
# Epoch: 158, Contrastive Loss: 9.1467, Loss: 1268.6438
# Epoch: 159, Contrastive Loss: 9.1466, Loss: 1268.1354
# Epoch: 160, Contrastive Loss: 9.1466, Loss: 1267.1538
# Epoch: 161, Contrastive Loss: 9.1466, Loss: 1265.8073
# Epoch: 162, Contrastive Loss: 9.1465, Loss: 1264.9731
# Epoch: 163, Contrastive Loss: 9.1465, Loss: 1264.0311
# Epoch: 164, Contrastive Loss: 9.1465, Loss: 1263.1101
# Epoch: 165, Contrastive Loss: 9.1464, Loss: 1261.8000
# Epoch: 166, Contrastive Loss: 9.1464, Loss: 1260.6390
# Epoch: 167, Contrastive Loss: 9.1463, Loss: 1259.7935
# Epoch: 168, Contrastive Loss: 9.1463, Loss: 1258.8436
# Epoch: 169, Contrastive Loss: 9.1462, Loss: 1257.5719
# Epoch: 170, Contrastive Loss: 9.1462, Loss: 1256.8160
# Epoch: 171, Contrastive Loss: 9.1461, Loss: 1255.5585
# Epoch: 172, Contrastive Loss: 9.1461, Loss: 1254.7188
# Epoch: 173, Contrastive Loss: 9.1461, Loss: 1253.3905
# Epoch: 174, Contrastive Loss: 9.1460, Loss: 1252.3799
# Epoch: 175, Contrastive Loss: 9.1460, Loss: 1251.3954
# Epoch: 176, Contrastive Loss: 9.1459, Loss: 1250.3546
# Epoch: 177, Contrastive Loss: 9.1459, Loss: 1249.4532
# Epoch: 178, Contrastive Loss: 9.1458, Loss: 1248.1849
# Epoch: 179, Contrastive Loss: 9.1458, Loss: 1247.0343
# Epoch: 180, Contrastive Loss: 9.1457, Loss: 1245.9594
# Epoch: 181, Contrastive Loss: 9.1457, Loss: 1245.0967
# Epoch: 182, Contrastive Loss: 9.1456, Loss: 1243.8608
# Epoch: 183, Contrastive Loss: 9.1456, Loss: 1242.7814
# Epoch: 184, Contrastive Loss: 9.1455, Loss: 1241.5995
# Epoch: 185, Contrastive Loss: 9.1455, Loss: 1240.5865
# Epoch: 186, Contrastive Loss: 9.1454, Loss: 1239.5321
# Epoch: 187, Contrastive Loss: 9.1453, Loss: 1238.3524
# Epoch: 188, Contrastive Loss: 9.1453, Loss: 1237.3196
# Epoch: 189, Contrastive Loss: 9.1452, Loss: 1236.2317
# Epoch: 190, Contrastive Loss: 9.1452, Loss: 1234.9196
# Epoch: 191, Contrastive Loss: 9.1451, Loss: 1233.7336
# Epoch: 192, Contrastive Loss: 9.1451, Loss: 1232.8505
# Epoch: 193, Contrastive Loss: 9.1450, Loss: 1231.9413
# Epoch: 194, Contrastive Loss: 9.1449, Loss: 1231.1539
# Epoch: 195, Contrastive Loss: 9.1449, Loss: 1229.9540
# Epoch: 196, Contrastive Loss: 9.1448, Loss: 1229.1699
# Epoch: 197, Contrastive Loss: 9.1448, Loss: 1227.8975
# Epoch: 198, Contrastive Loss: 9.1447, Loss: 1227.0242
# Epoch: 199, Contrastive Loss: 9.1446, Loss: 1226.3652
# Epoch: 200, Contrastive Loss: 9.1446, Loss: 1225.4753
# Epoch: 201, Contrastive Loss: 9.1445, Loss: 1224.4636
# Epoch: 202, Contrastive Loss: 9.1444, Loss: 1223.5100
# Epoch: 203, Contrastive Loss: 9.1444, Loss: 1222.5834
# Epoch: 204, Contrastive Loss: 9.1443, Loss: 1222.1837
# Epoch: 205, Contrastive Loss: 9.1442, Loss: 1220.8372
# Epoch: 206, Contrastive Loss: 9.1441, Loss: 1220.0710
# Epoch: 207, Contrastive Loss: 9.1441, Loss: 1219.2394
# Epoch: 208, Contrastive Loss: 9.1440, Loss: 1218.4702
# Epoch: 209, Contrastive Loss: 9.1439, Loss: 1217.7268
# Epoch: 210, Contrastive Loss: 9.1438, Loss: 1217.1603
# Epoch: 211, Contrastive Loss: 9.1437, Loss: 1216.2495
# Epoch: 212, Contrastive Loss: 9.1437, Loss: 1215.6702
# Epoch: 213, Contrastive Loss: 9.1436, Loss: 1214.4011
# Epoch: 214, Contrastive Loss: 9.1435, Loss: 1213.6989
# Epoch: 215, Contrastive Loss: 9.1434, Loss: 1213.0365
# Epoch: 216, Contrastive Loss: 9.1433, Loss: 1212.2708
# Epoch: 217, Contrastive Loss: 9.1431, Loss: 1211.6954
# Epoch: 218, Contrastive Loss: 9.1430, Loss: 1210.8042
# Epoch: 219, Contrastive Loss: 9.1429, Loss: 1210.3440
# Epoch: 220, Contrastive Loss: 9.1428, Loss: 1209.8380
# Epoch: 221, Contrastive Loss: 9.1427, Loss: 1208.9537
# Epoch: 222, Contrastive Loss: 9.1426, Loss: 1208.5385
# Epoch: 223, Contrastive Loss: 9.1425, Loss: 1207.6716
# Epoch: 224, Contrastive Loss: 9.1423, Loss: 1207.1051
# Epoch: 225, Contrastive Loss: 9.1422, Loss: 1206.9211
# Epoch: 226, Contrastive Loss: 9.1421, Loss: 1206.3070
# Epoch: 227, Contrastive Loss: 9.1419, Loss: 1205.4301
# Epoch: 228, Contrastive Loss: 9.1418, Loss: 1205.1451
# Epoch: 229, Contrastive Loss: 9.1417, Loss: 1204.5925
# Epoch: 230, Contrastive Loss: 9.1415, Loss: 1203.8767
# Epoch: 231, Contrastive Loss: 9.1414, Loss: 1203.6890
# Epoch: 232, Contrastive Loss: 9.1413, Loss: 1203.1516
# Epoch: 233, Contrastive Loss: 9.1411, Loss: 1202.5490
# Epoch: 234, Contrastive Loss: 9.1410, Loss: 1201.8480
# Epoch: 235, Contrastive Loss: 9.1408, Loss: 1202.0665
# Epoch: 236, Contrastive Loss: 9.1407, Loss: 1201.6270
# Epoch: 237, Contrastive Loss: 9.1406, Loss: 1201.2314
# Epoch: 238, Contrastive Loss: 9.1404, Loss: 1200.9591
# Epoch: 239, Contrastive Loss: 9.1403, Loss: 1200.1575
# Epoch: 240, Contrastive Loss: 9.1401, Loss: 1200.3417
# Epoch: 241, Contrastive Loss: 9.1400, Loss: 1199.8167
# Epoch: 242, Contrastive Loss: 9.1398, Loss: 1199.4214
# Epoch: 243, Contrastive Loss: 9.1397, Loss: 1199.0524
# Epoch: 244, Contrastive Loss: 9.1396, Loss: 1198.7675
# Epoch: 245, Contrastive Loss: 9.1394, Loss: 1198.7769
# Epoch: 246, Contrastive Loss: 9.1393, Loss: 1198.2759
# Epoch: 247, Contrastive Loss: 9.1391, Loss: 1197.9902
# Epoch: 248, Contrastive Loss: 9.1389, Loss: 1197.6256
# Epoch: 249, Contrastive Loss: 9.1388, Loss: 1197.8827
# Epoch: 250, Contrastive Loss: 9.1386, Loss: 1197.4396
# Epoch: 251, Contrastive Loss: 9.1384, Loss: 1196.9493
# Epoch: 252, Contrastive Loss: 9.1383, Loss: 1197.0934
# Epoch: 253, Contrastive Loss: 9.1381, Loss: 1196.5028
# Epoch: 254, Contrastive Loss: 9.1380, Loss: 1196.4827
# Epoch: 255, Contrastive Loss: 9.1378, Loss: 1196.0627
# Epoch: 256, Contrastive Loss: 9.1376, Loss: 1195.9728
# Epoch: 257, Contrastive Loss: 9.1374, Loss: 1195.6949
# Epoch: 258, Contrastive Loss: 9.1373, Loss: 1195.5896
# Epoch: 259, Contrastive Loss: 9.1371, Loss: 1195.2859
# Epoch: 260, Contrastive Loss: 9.1369, Loss: 1195.1129
# Epoch: 261, Contrastive Loss: 9.1367, Loss: 1194.9412
# Epoch: 262, Contrastive Loss: 9.1366, Loss: 1194.6996
# Epoch: 263, Contrastive Loss: 9.1364, Loss: 1194.4922
# Epoch: 264, Contrastive Loss: 9.1362, Loss: 1194.3530
# Epoch: 265, Contrastive Loss: 9.1360, Loss: 1194.0376
# Epoch: 266, Contrastive Loss: 9.1358, Loss: 1193.9622
# Epoch: 267, Contrastive Loss: 9.1356, Loss: 1193.6122
# Epoch: 268, Contrastive Loss: 9.1354, Loss: 1193.8693
# Epoch: 269, Contrastive Loss: 9.1351, Loss: 1193.4375
# Epoch: 270, Contrastive Loss: 9.1349, Loss: 1193.0377
# Epoch: 271, Contrastive Loss: 9.1347, Loss: 1193.0441
# Epoch: 272, Contrastive Loss: 9.1345, Loss: 1193.0593
# Epoch: 273, Contrastive Loss: 9.1342, Loss: 1192.8147
# Epoch: 274, Contrastive Loss: 9.1340, Loss: 1192.6743
# Epoch: 275, Contrastive Loss: 9.1337, Loss: 1192.6389
# Epoch: 276, Contrastive Loss: 9.1335, Loss: 1192.2445
# Epoch: 277, Contrastive Loss: 9.1332, Loss: 1192.0717
# Epoch: 278, Contrastive Loss: 9.1329, Loss: 1191.9060
# Epoch: 279, Contrastive Loss: 9.1326, Loss: 1191.7173
# Epoch: 280, Contrastive Loss: 9.1323, Loss: 1191.7480
# Epoch: 281, Contrastive Loss: 9.1320, Loss: 1191.5420
# Epoch: 282, Contrastive Loss: 9.1317, Loss: 1191.4070
# Epoch: 283, Contrastive Loss: 9.1314, Loss: 1191.2255
# Epoch: 284, Contrastive Loss: 9.1310, Loss: 1190.8566
# Epoch: 285, Contrastive Loss: 9.1307, Loss: 1191.0378
# Epoch: 286, Contrastive Loss: 9.1303, Loss: 1190.4623
# Epoch: 287, Contrastive Loss: 9.1299, Loss: 1190.3630
# Epoch: 288, Contrastive Loss: 9.1295, Loss: 1190.4097
# Epoch: 289, Contrastive Loss: 9.1291, Loss: 1190.2302
# Epoch: 290, Contrastive Loss: 9.1287, Loss: 1189.8722
# Epoch: 291, Contrastive Loss: 9.1282, Loss: 1189.8691
# Epoch: 292, Contrastive Loss: 9.1278, Loss: 1189.4600
# Epoch: 293, Contrastive Loss: 9.1273, Loss: 1189.5500
# Epoch: 294, Contrastive Loss: 9.1268, Loss: 1189.5066
# Epoch: 295, Contrastive Loss: 9.1262, Loss: 1189.1891
# Epoch: 296, Contrastive Loss: 9.1257, Loss: 1189.0590
# Epoch: 297, Contrastive Loss: 9.1251, Loss: 1189.1195
# Epoch: 298, Contrastive Loss: 9.1245, Loss: 1188.8885
# Epoch: 299, Contrastive Loss: 9.1238, Loss: 1188.5922
# Epoch: 300, Contrastive Loss: 9.1232, Loss: 1188.4382
# Epoch: 301, Contrastive Loss: 9.1225, Loss: 1188.4702
# Epoch: 302, Contrastive Loss: 9.1217, Loss: 1188.3324
# Epoch: 303, Contrastive Loss: 9.1209, Loss: 1188.1710
# Epoch: 304, Contrastive Loss: 9.1200, Loss: 1187.8652
# Epoch: 305, Contrastive Loss: 9.1192, Loss: 1187.7383
# Epoch: 306, Contrastive Loss: 9.1182, Loss: 1187.6093
# Epoch: 307, Contrastive Loss: 9.1171, Loss: 1187.4630
# Epoch: 308, Contrastive Loss: 9.1160, Loss: 1187.2322
# Epoch: 309, Contrastive Loss: 9.1148, Loss: 1187.1361
# Epoch: 310, Contrastive Loss: 9.1135, Loss: 1186.9050
# Epoch: 311, Contrastive Loss: 9.1121, Loss: 1187.0403
# Epoch: 312, Contrastive Loss: 9.1106, Loss: 1186.7988
# Epoch: 313, Contrastive Loss: 9.1090, Loss: 1186.4941
# Epoch: 314, Contrastive Loss: 9.1072, Loss: 1186.3192
# Epoch: 315, Contrastive Loss: 9.1052, Loss: 1186.1611
# Epoch: 316, Contrastive Loss: 9.1031, Loss: 1186.0160
# Epoch: 317, Contrastive Loss: 9.1009, Loss: 1185.7046
# Epoch: 318, Contrastive Loss: 9.0983, Loss: 1185.6533
# Epoch: 319, Contrastive Loss: 9.0954, Loss: 1185.6467
# Epoch: 320, Contrastive Loss: 9.0922, Loss: 1185.5216
# Epoch: 321, Contrastive Loss: 9.0887, Loss: 1185.1077
# Epoch: 322, Contrastive Loss: 9.0847, Loss: 1185.2448
# Epoch: 323, Contrastive Loss: 9.0800, Loss: 1184.8259
# Epoch: 324, Contrastive Loss: 9.0748, Loss: 1184.7390
# Epoch: 325, Contrastive Loss: 9.0688, Loss: 1184.5852
# Epoch: 326, Contrastive Loss: 9.0617, Loss: 1184.2524
# Epoch: 327, Contrastive Loss: 9.0531, Loss: 1183.9983
# Epoch: 328, Contrastive Loss: 9.0431, Loss: 1183.9124
# Epoch: 329, Contrastive Loss: 9.0313, Loss: 1183.5884
# Epoch: 330, Contrastive Loss: 9.0169, Loss: 1183.1423
# Epoch: 331, Contrastive Loss: 8.9991, Loss: 1183.1715
# Epoch: 332, Contrastive Loss: 8.9778, Loss: 1182.6295
# Epoch: 333, Contrastive Loss: 8.9525, Loss: 1182.4214
# Epoch: 334, Contrastive Loss: 8.9234, Loss: 1181.9019
# Epoch: 335, Contrastive Loss: 8.8913, Loss: 1181.2925
# Epoch: 336, Contrastive Loss: 8.8591, Loss: 1181.0966
# Epoch: 337, Contrastive Loss: 8.8311, Loss: 1180.6174
# Epoch: 338, Contrastive Loss: 8.8143, Loss: 1180.2618
# Epoch: 339, Contrastive Loss: 8.8145, Loss: 1180.1978
# Epoch: 340, Contrastive Loss: 8.8206, Loss: 1180.2643
# Epoch: 341, Contrastive Loss: 8.8062, Loss: 1179.8499
# Epoch: 342, Contrastive Loss: 8.7799, Loss: 1179.3362
# Epoch: 343, Contrastive Loss: 8.7590, Loss: 1179.2411
# Epoch: 344, Contrastive Loss: 8.7451, Loss: 1178.9821
# Epoch: 345, Contrastive Loss: 8.7341, Loss: 1178.6385
# Epoch: 346, Contrastive Loss: 8.7242, Loss: 1178.3086
# Epoch: 347, Contrastive Loss: 8.7149, Loss: 1178.2008
# Epoch: 348, Contrastive Loss: 8.7042, Loss: 1177.8800
# Epoch: 349, Contrastive Loss: 8.6905, Loss: 1177.6505
# Epoch: 350, Contrastive Loss: 8.6741, Loss: 1177.0350
# Epoch: 351, Contrastive Loss: 8.6542, Loss: 1176.9938
# Epoch: 352, Contrastive Loss: 8.6326, Loss: 1176.4567
# Epoch: 353, Contrastive Loss: 8.6139, Loss: 1176.3037
# Epoch: 354, Contrastive Loss: 8.6002, Loss: 1175.9133
# Epoch: 355, Contrastive Loss: 8.5912, Loss: 1175.7273
# Epoch: 356, Contrastive Loss: 8.5815, Loss: 1175.7141
# Epoch: 357, Contrastive Loss: 8.5686, Loss: 1175.3174
# Epoch: 358, Contrastive Loss: 8.5511, Loss: 1175.3473
# Epoch: 359, Contrastive Loss: 8.5319, Loss: 1174.7737
# Epoch: 360, Contrastive Loss: 8.5191, Loss: 1174.4028
# Epoch: 361, Contrastive Loss: 8.5123, Loss: 1174.3884
# Epoch: 362, Contrastive Loss: 8.5017, Loss: 1174.0802
# Epoch: 363, Contrastive Loss: 8.4933, Loss: 1173.7886
# Epoch: 364, Contrastive Loss: 8.4772, Loss: 1173.5061
# Epoch: 365, Contrastive Loss: 8.4630, Loss: 1173.5194
# Epoch: 366, Contrastive Loss: 8.4498, Loss: 1173.1149
# Epoch: 367, Contrastive Loss: 8.4408, Loss: 1173.1019
# Epoch: 368, Contrastive Loss: 8.4354, Loss: 1172.7676
# Epoch: 369, Contrastive Loss: 8.4299, Loss: 1172.5239
# Epoch: 370, Contrastive Loss: 8.4239, Loss: 1172.4783
# Epoch: 371, Contrastive Loss: 8.4176, Loss: 1172.2020
# Epoch: 372, Contrastive Loss: 8.4146, Loss: 1172.0946
# Epoch: 373, Contrastive Loss: 8.4033, Loss: 1171.8691
# Epoch: 374, Contrastive Loss: 8.4031, Loss: 1171.6694
# Epoch: 375, Contrastive Loss: 8.3979, Loss: 1171.6738
# Epoch: 376, Contrastive Loss: 8.3940, Loss: 1171.4236
# Epoch: 377, Contrastive Loss: 8.3888, Loss: 1171.2378
# Epoch: 378, Contrastive Loss: 8.3877, Loss: 1170.9991
# Epoch: 379, Contrastive Loss: 8.3779, Loss: 1170.7892
# Epoch: 380, Contrastive Loss: 8.3806, Loss: 1170.4834
# Epoch: 381, Contrastive Loss: 8.3709, Loss: 1170.5248
# Epoch: 382, Contrastive Loss: 8.3743, Loss: 1170.3744
# Epoch: 383, Contrastive Loss: 8.3663, Loss: 1170.1819
# Epoch: 384, Contrastive Loss: 8.3716, Loss: 1170.0951
# Epoch: 385, Contrastive Loss: 8.3604, Loss: 1169.8031
# Epoch: 386, Contrastive Loss: 8.3619, Loss: 1169.6964
# Epoch: 387, Contrastive Loss: 8.3561, Loss: 1169.6569
# Epoch: 388, Contrastive Loss: 8.3556, Loss: 1169.5759
# Epoch: 389, Contrastive Loss: 8.3522, Loss: 1169.3076
# Epoch: 390, Contrastive Loss: 8.3505, Loss: 1169.1801
# Epoch: 391, Contrastive Loss: 8.3485, Loss: 1168.9412
# Epoch: 392, Contrastive Loss: 8.3452, Loss: 1169.1737
# Epoch: 393, Contrastive Loss: 8.3438, Loss: 1168.9182
# Epoch: 394, Contrastive Loss: 8.3411, Loss: 1168.5616
# Epoch: 395, Contrastive Loss: 8.3394, Loss: 1168.8258
# Epoch: 396, Contrastive Loss: 8.3383, Loss: 1168.4962
# Epoch: 397, Contrastive Loss: 8.3349, Loss: 1168.1631
# Epoch: 398, Contrastive Loss: 8.3339, Loss: 1168.4141
# Epoch: 399, Contrastive Loss: 8.3316, Loss: 1167.9191
# Epoch: 400, Contrastive Loss: 8.3298, Loss: 1167.9858
# Epoch: 401, Contrastive Loss: 8.3281, Loss: 1167.7186
# Epoch: 402, Contrastive Loss: 8.3261, Loss: 1167.7869
# Epoch: 403, Contrastive Loss: 8.3250, Loss: 1167.3207
# Epoch: 404, Contrastive Loss: 8.3229, Loss: 1167.3043
# Epoch: 405, Contrastive Loss: 8.3219, Loss: 1167.0612
# Epoch: 406, Contrastive Loss: 8.3198, Loss: 1167.0940
# Epoch: 407, Contrastive Loss: 8.3192, Loss: 1166.9504
# Epoch: 408, Contrastive Loss: 8.3174, Loss: 1166.8766
# Epoch: 409, Contrastive Loss: 8.3159, Loss: 1166.7020
# Epoch: 410, Contrastive Loss: 8.3143, Loss: 1166.6998
# Epoch: 411, Contrastive Loss: 8.3135, Loss: 1166.3250
# Epoch: 412, Contrastive Loss: 8.3118, Loss: 1166.3763
# Epoch: 413, Contrastive Loss: 8.3108, Loss: 1166.4059
# Epoch: 414, Contrastive Loss: 8.3096, Loss: 1166.0974
# Epoch: 415, Contrastive Loss: 8.3081, Loss: 1165.9448
# Epoch: 416, Contrastive Loss: 8.3069, Loss: 1165.9686
# Epoch: 417, Contrastive Loss: 8.3055, Loss: 1165.6787
# Epoch: 418, Contrastive Loss: 8.3044, Loss: 1165.5831
# Epoch: 419, Contrastive Loss: 8.3032, Loss: 1165.5162
# Epoch: 420, Contrastive Loss: 8.3023, Loss: 1165.5519
# Epoch: 421, Contrastive Loss: 8.3006, Loss: 1165.2507
# Epoch: 422, Contrastive Loss: 8.2994, Loss: 1165.0380
# Epoch: 423, Contrastive Loss: 8.2984, Loss: 1165.0361
# Epoch: 424, Contrastive Loss: 8.2970, Loss: 1164.8113
# Epoch: 425, Contrastive Loss: 8.2959, Loss: 1164.9620
# Epoch: 426, Contrastive Loss: 8.2948, Loss: 1164.8756
# Epoch: 427, Contrastive Loss: 8.2933, Loss: 1164.4963
# Epoch: 428, Contrastive Loss: 8.2921, Loss: 1164.3533
# Epoch: 429, Contrastive Loss: 8.2909, Loss: 1164.2821
# Epoch: 430, Contrastive Loss: 8.2895, Loss: 1164.1122
# Epoch: 431, Contrastive Loss: 8.2884, Loss: 1163.8312
# Epoch: 432, Contrastive Loss: 8.2871, Loss: 1163.7407
# Epoch: 433, Contrastive Loss: 8.2860, Loss: 1163.9087
# Epoch: 434, Contrastive Loss: 8.2852, Loss: 1163.7755
# Epoch: 435, Contrastive Loss: 8.2833, Loss: 1163.6107
# Epoch: 436, Contrastive Loss: 8.2819, Loss: 1163.5754
# Epoch: 437, Contrastive Loss: 8.2810, Loss: 1163.1952
# Epoch: 438, Contrastive Loss: 8.2793, Loss: 1163.1193
# Epoch: 439, Contrastive Loss: 8.2784, Loss: 1163.1777
# Epoch: 440, Contrastive Loss: 8.2773, Loss: 1162.6965
# Epoch: 441, Contrastive Loss: 8.2758, Loss: 1162.9438
# Epoch: 442, Contrastive Loss: 8.2751, Loss: 1162.9667
# Epoch: 443, Contrastive Loss: 8.2738, Loss: 1162.3169
# Epoch: 444, Contrastive Loss: 8.2736, Loss: 1162.3796
# Epoch: 445, Contrastive Loss: 8.2736, Loss: 1162.1589
# Epoch: 446, Contrastive Loss: 8.2716, Loss: 1162.0852
# Epoch: 447, Contrastive Loss: 8.2727, Loss: 1162.0488
# Epoch: 448, Contrastive Loss: 8.2683, Loss: 1161.8038
# Epoch: 449, Contrastive Loss: 8.2693, Loss: 1161.6062
# Epoch: 450, Contrastive Loss: 8.2658, Loss: 1161.7621
# Epoch: 451, Contrastive Loss: 8.2662, Loss: 1161.2639
# Epoch: 452, Contrastive Loss: 8.2631, Loss: 1161.2858
# Epoch: 453, Contrastive Loss: 8.2636, Loss: 1161.2683
# Epoch: 454, Contrastive Loss: 8.2607, Loss: 1160.9116
# Epoch: 455, Contrastive Loss: 8.2607, Loss: 1160.9694
# Epoch: 456, Contrastive Loss: 8.2663, Loss: 1160.7826
# Epoch: 457, Contrastive Loss: 8.2602, Loss: 1160.6910
# Epoch: 458, Contrastive Loss: 8.2743, Loss: 1160.7634
# Epoch: 459, Contrastive Loss: 8.2769, Loss: 1160.4852
# Epoch: 460, Contrastive Loss: 8.2565, Loss: 1160.1146
# Epoch: 461, Contrastive Loss: 8.2654, Loss: 1160.0920
# Epoch: 462, Contrastive Loss: 8.2557, Loss: 1159.8279
# Epoch: 463, Contrastive Loss: 8.2572, Loss: 1159.6740
# Epoch: 464, Contrastive Loss: 8.2529, Loss: 1159.8755
# Epoch: 465, Contrastive Loss: 8.2525, Loss: 1159.4509
# Epoch: 466, Contrastive Loss: 8.2488, Loss: 1159.2457
# Epoch: 467, Contrastive Loss: 8.2488, Loss: 1159.0657
# Epoch: 468, Contrastive Loss: 8.2453, Loss: 1159.1328
# Epoch: 469, Contrastive Loss: 8.2473, Loss: 1158.7186
# Epoch: 470, Contrastive Loss: 8.2447, Loss: 1158.8663
# Epoch: 471, Contrastive Loss: 8.2532, Loss: 1158.9648
# Epoch: 472, Contrastive Loss: 8.2432, Loss: 1158.2952
# Epoch: 473, Contrastive Loss: 8.2438, Loss: 1158.4081
# Epoch: 474, Contrastive Loss: 8.2432, Loss: 1158.1984
# Epoch: 475, Contrastive Loss: 8.2397, Loss: 1157.8391
# Epoch: 476, Contrastive Loss: 8.2403, Loss: 1157.8540
# Epoch: 477, Contrastive Loss: 8.2365, Loss: 1157.8180
# Epoch: 478, Contrastive Loss: 8.2374, Loss: 1157.3777
# Epoch: 479, Contrastive Loss: 8.2337, Loss: 1157.2938
# Epoch: 480, Contrastive Loss: 8.2333, Loss: 1157.2554
# Epoch: 481, Contrastive Loss: 8.2332, Loss: 1157.0061
# Epoch: 482, Contrastive Loss: 8.2297, Loss: 1157.2346
# Epoch: 483, Contrastive Loss: 8.2312, Loss: 1156.7739
# Epoch: 484, Contrastive Loss: 8.2277, Loss: 1156.6694
# Epoch: 485, Contrastive Loss: 8.2281, Loss: 1156.6146
# Epoch: 486, Contrastive Loss: 8.2260, Loss: 1156.4763
# Epoch: 487, Contrastive Loss: 8.2244, Loss: 1156.3296
# Epoch: 488, Contrastive Loss: 8.2248, Loss: 1156.0413
# Epoch: 489, Contrastive Loss: 8.2222, Loss: 1155.8971
# Epoch: 490, Contrastive Loss: 8.2228, Loss: 1155.8427
# Epoch: 491, Contrastive Loss: 8.2236, Loss: 1155.8104
# Epoch: 492, Contrastive Loss: 8.2198, Loss: 1155.7769
# Epoch: 493, Contrastive Loss: 8.2213, Loss: 1155.6727
# Epoch: 494, Contrastive Loss: 8.2195, Loss: 1155.3741
# Epoch: 495, Contrastive Loss: 8.2179, Loss: 1155.4174
# Epoch: 496, Contrastive Loss: 8.2170, Loss: 1155.2607
# Epoch: 497, Contrastive Loss: 8.2159, Loss: 1154.9240
# Epoch: 498, Contrastive Loss: 8.2152, Loss: 1154.8640
# Epoch: 499, Contrastive Loss: 8.2140, Loss: 1154.8438

# %%
import matplotlib.pyplot as plt

plt.plot(gdata.uns['arch_loss'])
plt.show()

# %%
df
# Out:
#             0         1         2         3         4         5         6   \
# 0_22  3.111076 -2.027663 -0.436260  1.151151  3.429740  3.279073 -3.338529
# 0_33  3.779803 -1.759752  0.800436  0.438440  3.280641  3.946389  0.327449
# 0_40  5.265553 -2.246657  1.261908  1.193160  3.001423  5.138677 -0.265029
# 0_41  4.470261 -1.789021  0.901425  0.811141  3.191497  4.286327 -0.185880
# 0_42  4.006275 -1.840013  0.875486  0.149134  2.969945  3.799552  0.161701
# ...        ...       ...       ...       ...       ...       ...       ...
# 9_73  3.856407 -1.720548  0.912155  0.803886  3.414831  3.578523  0.481286
# 9_74  3.950883 -1.217314  1.758504  0.462527  2.629118  3.537797  1.473411
# 9_75  4.321431 -2.056416  0.882603  0.490813  3.354023  4.100780  0.111936
# 9_8   2.240320 -0.492107 -0.011205 -0.866556  1.880824  0.982952  0.354897
# 9_9   3.751971 -1.762162  1.167166  0.197270  3.007378  3.387728 -0.098387
#
#             7         8         9   ...        20        21        22  \
# 0_22 -2.137873  6.522508  2.417771  ...  4.555326 -5.753746 -3.794203
# 0_33 -3.160053  2.832088  1.790311  ...  1.427668 -3.207786 -1.471913
# 0_40 -3.040566  3.807597  1.714878  ...  2.829588 -4.513958 -1.483883
# 0_41 -3.173630  3.396251  1.475126  ...  2.454682 -3.562897 -1.920600
# 0_42 -3.107027  2.814280  1.702195  ...  1.722134 -2.975174 -1.466880
# ...        ...       ...       ...  ...       ...       ...       ...
# 9_73 -3.046239  2.895064  2.198785  ...  1.303679 -3.727710 -1.477843
# 9_74 -2.261731  3.122206  3.221665  ...  1.549170 -4.083993 -0.534568
# 9_75 -3.360111  3.139153  1.744617  ...  2.070745 -3.443500 -1.754682
# 9_8  -2.385214  1.388919  1.013304  ...  0.768454 -1.287813 -1.157446
# 9_9  -3.152412  2.801797  1.870195  ...  1.885850 -3.073836 -1.572643
#
#             23        24        25        26        27        28        29
# 0_22 -1.608239  0.228450  2.830864  3.795726  0.228874  3.166040  2.592494
# 0_33 -6.431776  1.198391  4.069748  4.893527 -1.635050  4.652557  3.547627
# 0_40 -7.450413  0.729119  4.166203  4.081739 -1.360025  4.247457  3.583359
# 0_41 -6.520609  0.501323  4.265707  4.393836 -1.121702  4.578705  3.365890
# 0_42 -6.733867  1.082242  4.085644  4.422255 -1.562882  4.346913  3.491328
# ...        ...       ...       ...       ...       ...       ...       ...
# 9_73 -6.261795  1.213369  4.005834  4.803931 -1.472516  4.450393  3.511879
# 9_74 -5.543495  0.845808  4.097846  3.755259 -0.278383  4.282956  3.465004
# 9_75 -7.068357  1.014014  4.300282  4.889418 -1.518948  4.516804  3.674100
# 9_8  -4.237789  0.732026  2.154086  3.307718 -0.172809  2.172959  2.011898
# 9_9  -6.112729  0.981767  3.861346  4.521570 -1.483150  4.063215  3.347591
#
# [4697 rows x 30 columns]

# %%
# Write the 'data' variable to a file in CSV format
np.savetxt('data.csv', gdata.obsm['MY_ARCH'], delimiter=',')

# %% [markdown]
# SpatialGlue Clustering Codes

# %%
import pickle
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

import os
os.environ["R_HOME"] = 'C:/Users/AGNISH/.conda/envs/GraphST/Lib/R/'
# os.environ["PATH"]   = r"C:\Program Files\R\R-4.3.0\bin\x64" + ";" + os.environ["PATH"]
import rpy2
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri, packages
pandas2ri.activate()
stats = packages.importr('stats')
  

def mclust_R(adata, num_cluster, modelNames='EEE', used_obsm='emb_pca', random_seed=2020):
    """\
    Clustering using the mclust algorithm.
    The parameters are the same as those in the R package mclust.
    """
    
    np.random.seed(random_seed)
    
    robjects.r.library("mclust")

    import rpy2.robjects.numpy2ri
    rpy2.robjects.numpy2ri.activate()
    r_random_seed = robjects.r['set.seed']
    r_random_seed(random_seed)
    rmclust = robjects.r['Mclust']
    
    res = rmclust(rpy2.robjects.numpy2ri.numpy2rpy(adata.obsm[used_obsm]), num_cluster, modelNames)
    mclust_res = np.array(res[-2])

    adata.obs['mclust'] = mclust_res
    adata.obs['mclust'] = adata.obs['mclust'].astype('int')
    adata.obs['mclust'] = adata.obs['mclust'].astype('category')
    return adata

def clustering(adata, n_clusters=8, key='emb', add_key='SpatialGlue', method='mclust', start=0.1, end=3.0, increment=0.01, use_pca=False):
    """\
    Spatial clustering based the latent representation.

    Parameters
    ----------
    adata : anndata
        AnnData object of scanpy package.
    n_clusters : int, optional
        The number of clusters. The default is 7.
    key : string, optional
        The key of the input representation in adata.obsm. The default is 'emb'.
    method : string, optional
        The tool for clustering. Supported tools include 'mclust', 'leiden', and 'louvain'. The default is 'mclust'. 
    start : float
        The start value for searching. The default is 0.1. Only works if the clustering method is 'leiden' or 'louvain'.
    end : float 
        The end value for searching. The default is 3.0. Only works if the clustering method is 'leiden' or 'louvain'.
    increment : float
        The step size to increase. The default is 0.01. Only works if the clustering method is 'leiden' or 'louvain'.  
    use_pca : bool, optional
        Whether use pca for dimension reduction. The default is false.

    Returns
    -------
    None.

    """
    
    if use_pca:
       pca = PCA(n_components=20, random_state=42) 
       adata.obsm[key + '_pca'] = pca.fit_transform(adata.obsm[key].copy())
    
    if method == 'mclust':
       if use_pca: 
          adata = mclust_R(adata, used_obsm=key + '_pca', num_cluster=n_clusters)
       else:
          adata = mclust_R(adata, used_obsm=key, num_cluster=n_clusters)
       adata.obs[add_key] = adata.obs['mclust']
    elif method == 'leiden':
       if use_pca: 
          res = search_res(adata, n_clusters, use_rep=key + '_pca', method=method, start=start, end=end, increment=increment)
       else:
          res = search_res(adata, n_clusters, use_rep=key, method=method, start=start, end=end, increment=increment) 
       sc.tl.leiden(adata, random_state=0, resolution=res)
       adata.obs[add_key] = adata.obs['leiden']
    elif method == 'louvain':
       if use_pca: 
          res = search_res(adata, n_clusters, use_rep=key + '_pca', method=method, start=start, end=end, increment=increment)
       else:
          res = search_res(adata, n_clusters, use_rep=key, method=method, start=start, end=end, increment=increment) 
       sc.tl.louvain(adata, random_state=0, resolution=res)
       adata.obs[add_key] = adata.obs['louvain']
       
def search_res(adata, n_clusters, method='leiden', use_rep='emb', start=0.1, end=3.0, increment=0.01):
    '''\
    Searching corresponding resolution according to given cluster number
    
    Parameters
    ----------
    adata : anndata
        AnnData object of spatial data.
    n_clusters : int
        Targetting number of clusters.
    method : string
        Tool for clustering. Supported tools include 'leiden' and 'louvain'. The default is 'leiden'.    
    use_rep : string
        The indicated representation for clustering.
    start : float
        The start value for searching.
    end : float 
        The end value for searching.
    increment : float
        The step size to increase.
        
    Returns
    -------
    res : float
        Resolution.
        
    '''
    print('Searching resolution...')
    label = 0
    sc.pp.neighbors(adata, n_neighbors=50, use_rep=use_rep)
    for res in sorted(list(np.arange(start, end, increment)), reverse=True):
        if method == 'leiden':
           sc.tl.leiden(adata, random_state=0, resolution=res)
           count_unique = len(pd.DataFrame(adata.obs['leiden']).leiden.unique())
           print('resolution={}, cluster number={}'.format(res, count_unique))
        elif method == 'louvain':
           sc.tl.louvain(adata, random_state=0, resolution=res)
           count_unique = len(pd.DataFrame(adata.obs['louvain']).louvain.unique()) 
           print('resolution={}, cluster number={}'.format(res, count_unique))
        if count_unique == n_clusters:
            label = 1
            break

    assert label==1, "Resolution is not found. Please try bigger range or smaller step!." 
       
    return res     

def plot_weight_value(alpha, label, modality1='mRNA', modality2='protein'):
  """\
  Plotting weight values
  
  """  
  import pandas as pd  
  
  df = pd.DataFrame(columns=[modality1, modality2, 'label'])  
  df[modality1], df[modality2] = alpha[:, 0], alpha[:, 1]
  df['label'] = label
  df = df.set_index('label').stack().reset_index()
  df.columns = ['label_SpatialGlue', 'Modality', 'Weight value']
  ax = sns.violinplot(data=df, x='label_SpatialGlue', y='Weight value', hue="Modality",
                split=True, inner="quart", linewidth=1, show=False)
  ax.set_title(modality1 + ' vs ' + modality2) 

  plt.tight_layout(w_pad=0.05)
  plt.show()

# %%
for tool in ['mclust','leiden','louvain']:
   # we use mcluster as clustering tool by default.
   print(tool)

   # performing PCA
   gdata.obsm['emb_combined_pca'] = sc.tl.pca(gdata.obsm['MY_ARCH'], n_comps=20)

   # clustering
   if tool == 'mclust':
      clustering(gdata, key='emb_combined_pca', add_key='1', n_clusters=8, method=tool)
   elif tool in ['leiden']:
      clustering(gdata, key='emb_combined_pca', add_key='2', n_clusters=8, method=tool, start=0.1, end=2.0, increment=0.01)
   elif tool in ['louvain']:
      clustering(gdata, key='emb_combined_pca', add_key='3', n_clusters=8, method=tool, start=0.1, end=2.0, increment=0.01)
# Out:
# R[write to console]:                    __           __
#    ____ ___  _____/ /_  _______/ /_
#   / __ `__ \/ ___/ / / / / ___/ __/
#  / / / / / / /__/ / /_/ (__  ) /_
# /_/ /_/ /_/\___/_/\__,_/____/\__/   version 5.4.10
# Type 'citation("mclust")' for citing this R package in publications.
# mclust
# fitting ...
#   |======================================================================| 100%
# leiden
# Searching resolution...
# resolution=1.989999999999999, cluster number=20
# resolution=1.979999999999999, cluster number=21
# resolution=1.969999999999999, cluster number=21
# resolution=1.959999999999999, cluster number=20
# resolution=1.949999999999999, cluster number=21
# resolution=1.939999999999999, cluster number=20
# resolution=1.9299999999999993, cluster number=21
# resolution=1.9199999999999993, cluster number=20
# resolution=1.9099999999999993, cluster number=21
# resolution=1.8999999999999992, cluster number=21
# resolution=1.8899999999999992, cluster number=22
# resolution=1.8799999999999992, cluster number=22
# resolution=1.8699999999999992, cluster number=21
# resolution=1.8599999999999992, cluster number=21
# resolution=1.8499999999999992, cluster number=21
# resolution=1.8399999999999992, cluster number=20
# resolution=1.8299999999999992, cluster number=20
# resolution=1.8199999999999992, cluster number=21
# resolution=1.8099999999999992, cluster number=19
# resolution=1.7999999999999992, cluster number=21
# resolution=1.7899999999999991, cluster number=20
# resolution=1.7799999999999994, cluster number=21
# resolution=1.7699999999999994, cluster number=21
# resolution=1.7599999999999993, cluster number=20
# resolution=1.7499999999999993, cluster number=20
# resolution=1.7399999999999993, cluster number=20
# resolution=1.7299999999999993, cluster number=21
# resolution=1.7199999999999993, cluster number=21
# resolution=1.7099999999999993, cluster number=20
# resolution=1.6999999999999993, cluster number=21
# resolution=1.6899999999999993, cluster number=20
# resolution=1.6799999999999993, cluster number=20
# resolution=1.6699999999999993, cluster number=19
# resolution=1.6599999999999993, cluster number=19
# resolution=1.6499999999999992, cluster number=19
# resolution=1.6399999999999992, cluster number=21
# resolution=1.6299999999999992, cluster number=20
# resolution=1.6199999999999992, cluster number=19
# resolution=1.6099999999999994, cluster number=19
# resolution=1.5999999999999994, cluster number=18
# resolution=1.5899999999999994, cluster number=19
# resolution=1.5799999999999994, cluster number=17
# resolution=1.5699999999999994, cluster number=19
# resolution=1.5599999999999994, cluster number=19
# resolution=1.5499999999999994, cluster number=20
# resolution=1.5399999999999994, cluster number=19
# resolution=1.5299999999999994, cluster number=18
# resolution=1.5199999999999994, cluster number=17
# resolution=1.5099999999999993, cluster number=16
# resolution=1.4999999999999993, cluster number=19
# resolution=1.4899999999999993, cluster number=19
# resolution=1.4799999999999993, cluster number=18
# resolution=1.4699999999999993, cluster number=18
# resolution=1.4599999999999995, cluster number=18
# resolution=1.4499999999999995, cluster number=19
# resolution=1.4399999999999995, cluster number=17
# resolution=1.4299999999999995, cluster number=18
# resolution=1.4199999999999995, cluster number=16
# resolution=1.4099999999999995, cluster number=16
# resolution=1.3999999999999995, cluster number=16
# resolution=1.3899999999999995, cluster number=17
# resolution=1.3799999999999994, cluster number=16
# resolution=1.3699999999999994, cluster number=15
# resolution=1.3599999999999994, cluster number=17
# resolution=1.3499999999999994, cluster number=18
# resolution=1.3399999999999994, cluster number=16
# resolution=1.3299999999999994, cluster number=17
# resolution=1.3199999999999994, cluster number=17
# resolution=1.3099999999999994, cluster number=18
# resolution=1.2999999999999994, cluster number=17
# resolution=1.2899999999999996, cluster number=15
# resolution=1.2799999999999996, cluster number=15
# resolution=1.2699999999999996, cluster number=16
# resolution=1.2599999999999996, cluster number=16
# resolution=1.2499999999999996, cluster number=16
# resolution=1.2399999999999995, cluster number=16
# resolution=1.2299999999999995, cluster number=15
# resolution=1.2199999999999995, cluster number=15
# resolution=1.2099999999999995, cluster number=15
# resolution=1.1999999999999995, cluster number=15
# resolution=1.1899999999999995, cluster number=15
# resolution=1.1799999999999995, cluster number=15
# resolution=1.1699999999999995, cluster number=14
# resolution=1.1599999999999995, cluster number=14
# resolution=1.1499999999999995, cluster number=16
# resolution=1.1399999999999997, cluster number=14
# resolution=1.1299999999999997, cluster number=14
# resolution=1.1199999999999997, cluster number=15
# resolution=1.1099999999999997, cluster number=14
# resolution=1.0999999999999996, cluster number=13
# resolution=1.0899999999999996, cluster number=14
# resolution=1.0799999999999996, cluster number=13
# resolution=1.0699999999999996, cluster number=14
# resolution=1.0599999999999996, cluster number=14
# resolution=1.0499999999999996, cluster number=14
# resolution=1.0399999999999996, cluster number=13
# resolution=1.0299999999999996, cluster number=12
# resolution=1.0199999999999996, cluster number=14
# resolution=1.0099999999999996, cluster number=14
# resolution=0.9999999999999996, cluster number=14
# resolution=0.9899999999999995, cluster number=13
# resolution=0.9799999999999995, cluster number=13
# resolution=0.9699999999999995, cluster number=12
# resolution=0.9599999999999995, cluster number=11
# resolution=0.9499999999999995, cluster number=13
# resolution=0.9399999999999996, cluster number=10
# resolution=0.9299999999999996, cluster number=10
# resolution=0.9199999999999996, cluster number=12
# resolution=0.9099999999999996, cluster number=12
# resolution=0.8999999999999996, cluster number=11
# resolution=0.8899999999999996, cluster number=9
# resolution=0.8799999999999996, cluster number=9
# resolution=0.8699999999999996, cluster number=11
# resolution=0.8599999999999995, cluster number=10
# resolution=0.8499999999999996, cluster number=10
# resolution=0.8399999999999996, cluster number=9
# resolution=0.8299999999999996, cluster number=10
# resolution=0.8199999999999996, cluster number=9
# resolution=0.8099999999999996, cluster number=9
# resolution=0.7999999999999996, cluster number=9
# resolution=0.7899999999999996, cluster number=9
# resolution=0.7799999999999997, cluster number=11
# resolution=0.7699999999999997, cluster number=9
# resolution=0.7599999999999997, cluster number=8
# louvain
# Searching resolution...
# resolution=1.989999999999999, cluster number=16
# resolution=1.979999999999999, cluster number=16
# resolution=1.969999999999999, cluster number=17
# resolution=1.959999999999999, cluster number=16
# resolution=1.949999999999999, cluster number=17
# resolution=1.939999999999999, cluster number=17
# resolution=1.9299999999999993, cluster number=15
# resolution=1.9199999999999993, cluster number=14
# resolution=1.9099999999999993, cluster number=16
# resolution=1.8999999999999992, cluster number=17
# resolution=1.8899999999999992, cluster number=16
# resolution=1.8799999999999992, cluster number=16
# resolution=1.8699999999999992, cluster number=16
# resolution=1.8599999999999992, cluster number=16
# resolution=1.8499999999999992, cluster number=16
# resolution=1.8399999999999992, cluster number=15
# resolution=1.8299999999999992, cluster number=15
# resolution=1.8199999999999992, cluster number=16
# resolution=1.8099999999999992, cluster number=16
# resolution=1.7999999999999992, cluster number=16
# resolution=1.7899999999999991, cluster number=15
# resolution=1.7799999999999994, cluster number=15
# resolution=1.7699999999999994, cluster number=15
# resolution=1.7599999999999993, cluster number=15
# resolution=1.7499999999999993, cluster number=14
# resolution=1.7399999999999993, cluster number=14
# resolution=1.7299999999999993, cluster number=14
# resolution=1.7199999999999993, cluster number=14
# resolution=1.7099999999999993, cluster number=14
# resolution=1.6999999999999993, cluster number=14
# resolution=1.6899999999999993, cluster number=14
# resolution=1.6799999999999993, cluster number=13
# resolution=1.6699999999999993, cluster number=13
# resolution=1.6599999999999993, cluster number=13
# resolution=1.6499999999999992, cluster number=14
# resolution=1.6399999999999992, cluster number=13
# resolution=1.6299999999999992, cluster number=12
# resolution=1.6199999999999992, cluster number=13
# resolution=1.6099999999999994, cluster number=14
# resolution=1.5999999999999994, cluster number=14
# resolution=1.5899999999999994, cluster number=12
# resolution=1.5799999999999994, cluster number=13
# resolution=1.5699999999999994, cluster number=13
# resolution=1.5599999999999994, cluster number=13
# resolution=1.5499999999999994, cluster number=13
# resolution=1.5399999999999994, cluster number=13
# resolution=1.5299999999999994, cluster number=12
# resolution=1.5199999999999994, cluster number=13
# resolution=1.5099999999999993, cluster number=13
# resolution=1.4999999999999993, cluster number=12
# resolution=1.4899999999999993, cluster number=11
# resolution=1.4799999999999993, cluster number=12
# resolution=1.4699999999999993, cluster number=13
# resolution=1.4599999999999995, cluster number=12
# resolution=1.4499999999999995, cluster number=13
# resolution=1.4399999999999995, cluster number=12
# resolution=1.4299999999999995, cluster number=12
# resolution=1.4199999999999995, cluster number=11
# resolution=1.4099999999999995, cluster number=11
# resolution=1.3999999999999995, cluster number=11
# resolution=1.3899999999999995, cluster number=13
# resolution=1.3799999999999994, cluster number=13
# resolution=1.3699999999999994, cluster number=12
# resolution=1.3599999999999994, cluster number=12
# resolution=1.3499999999999994, cluster number=11
# resolution=1.3399999999999994, cluster number=11
# resolution=1.3299999999999994, cluster number=11
# resolution=1.3199999999999994, cluster number=11
# resolution=1.3099999999999994, cluster number=11
# resolution=1.2999999999999994, cluster number=11
# resolution=1.2899999999999996, cluster number=11
# resolution=1.2799999999999996, cluster number=11
# resolution=1.2699999999999996, cluster number=11
# resolution=1.2599999999999996, cluster number=11
# resolution=1.2499999999999996, cluster number=11
# resolution=1.2399999999999995, cluster number=11
# resolution=1.2299999999999995, cluster number=11
# resolution=1.2199999999999995, cluster number=11
# resolution=1.2099999999999995, cluster number=11
# resolution=1.1999999999999995, cluster number=11
# resolution=1.1899999999999995, cluster number=11
# resolution=1.1799999999999995, cluster number=11
# resolution=1.1699999999999995, cluster number=11
# resolution=1.1599999999999995, cluster number=11
# resolution=1.1499999999999995, cluster number=10
# resolution=1.1399999999999997, cluster number=11
# resolution=1.1299999999999997, cluster number=10
# resolution=1.1199999999999997, cluster number=10
# resolution=1.1099999999999997, cluster number=10
# resolution=1.0999999999999996, cluster number=10
# resolution=1.0899999999999996, cluster number=10
# resolution=1.0799999999999996, cluster number=9
# resolution=1.0699999999999996, cluster number=9
# resolution=1.0599999999999996, cluster number=9
# resolution=1.0499999999999996, cluster number=9
# resolution=1.0399999999999996, cluster number=9
# resolution=1.0299999999999996, cluster number=9
# resolution=1.0199999999999996, cluster number=9
# resolution=1.0099999999999996, cluster number=9
# resolution=0.9999999999999996, cluster number=10
# resolution=0.9899999999999995, cluster number=9
# resolution=0.9799999999999995, cluster number=9
# resolution=0.9699999999999995, cluster number=8

# %%
# visualization Mclust
fig, ax_list = plt.subplots(1, 2, figsize=(12, 5))
sc.pp.neighbors(gdata, use_rep='emb_combined_pca', n_neighbors=10)
sc.tl.umap(gdata)

sc.pl.umap(gdata, color='1', ax=ax_list[0], title='mclust', s=60, show=False)
sc.pl.embedding(gdata, basis='spatial', color='1', ax=ax_list[1], title='mclust', s=90, show=False)

plt.tight_layout(w_pad=0.3)
plt.show()

# %%
# visualization leiden
fig, ax_list = plt.subplots(1, 2, figsize=(12, 5))
sc.pp.neighbors(gdata, use_rep='emb_combined_pca', n_neighbors=10)
sc.tl.umap(gdata)

sc.pl.umap(gdata, color='2', ax=ax_list[0], title='leiden', s=60, show=False)
sc.pl.embedding(gdata, basis='spatial', color='2', ax=ax_list[1], title='leiden', s=90, show=False)

plt.tight_layout(w_pad=0.3)
plt.show()

# %%
# visualization louven
fig, ax_list = plt.subplots(1, 2, figsize=(12, 5))
sc.pp.neighbors(gdata, use_rep='emb_combined_pca', n_neighbors=10)
sc.tl.umap(gdata)

sc.pl.umap(gdata, color='3', ax=ax_list[0], title='louvain', s=60, show=False)
sc.pl.embedding(gdata, basis='spatial', color='3', ax=ax_list[1], title='louvain', s=90, show=False)

plt.tight_layout(w_pad=0.3)
plt.show()
