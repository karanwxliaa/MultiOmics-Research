# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import os
import sys

# %%
import STAGATE
import scanpy as sc

# %%
file = ''
adata = sc.read_visium(file, count_file=r'GSE198353_spleen_rep_2_filtered_feature_bc_matrix.h5',load_images=True)
adata.var_names_make_unique()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2768 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
#Normalization
sc.pp.highly_variable_genes(adata, flavor="seurat_v3", n_top_genes=3000)
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
from sklearn.metrics.cluster import adjusted_rand_score

# %%
STAGATE.Cal_Spatial_Net(adata, rad_cutoff=150)
STAGATE.Stats_Spatial_Net(adata)
# Out:
# ------Calculating spatial graph...
# The graph contains 182542 edges, 2768 cells.
# 65.9473 neighbors per cell on average.

# %%
adata = STAGATE.train_STAGATE(adata, alpha=0)
# Out:
# Size of Input:  (2768, 3000)
# 100%|██████████| 500/500 [05:48<00:00,  1.43it/s]

# %%
r"C:\Users\KARAN\AppData\Local\R\win-library\4.3\spatialLIBD\data"
# Out:
# 'C:\\Users\\KARAN\\AppData\\Local\\R\\win-library\\4.3\\spatialLIBD\\data'

# %%
os.environ['R_HOME'] = r"C:\Program Files\R\R-4.3.0"
os.environ['R_USER'] = r"C:\Users\KARAN\anaconda3\envs\STAGATE_PT\Lib\site-packages\rpy2"

# %%
sc.pp.neighbors(adata, use_rep='STAGATE')
sc.tl.umap(adata)
adata = STAGATE.mclust_R(adata, used_obsm='STAGATE', num_cluster=7)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 3
#       1 sc.pp.neighbors(adata, use_rep='STAGATE')
#       2 sc.tl.umap(adata)
# ----> 3 adata = STAGATE.mclust_R(adata, used_obsm='STAGATE', num_cluster=7)
#
# File c:\Users\KARAN\anaconda3\envs\STAGATE_PT\lib\site-packages\stagate-1.0.1-py3.9.egg\STAGATE\utils.py:161, in mclust_R(adata, num_cluster, modelNames, used_obsm, random_seed)
#     155 """\
#     156 Clustering using the mclust algorithm.
#     157 The parameters are the same as those in the R package mclust.
#     158 """
#     160 np.random.seed(random_seed)
# --> 161 import rpy2.robjects as robjects
#     162 robjects.r.library("mclust")
#     164 import rpy2.robjects.numpy2ri
#
# File c:\Users\KARAN\anaconda3\envs\STAGATE_PT\lib\site-packages\rpy2\robjects\__init__.py:15
#      13 import types
#      14 import typing
# ---> 15 import rpy2.rinterface as rinterface
#      16 import rpy2.rlike.container as rlc
#      18 from rpy2.robjects.robject import RObjectMixin, RObject
#
# File c:\Users\KARAN\anaconda3\envs\STAGATE_PT\lib\site-packages\rpy2\rinterface.py:16
#      14 import warnings
#      15 from typing import Union
# ---> 16 from rpy2.rinterface_lib import openrlib
#      17 import rpy2.rinterface_lib._rinterface_capi as _rinterface
#      18 import rpy2.rinterface_lib.embedded as embedded
#
# File c:\Users\KARAN\anaconda3\envs\STAGATE_PT\lib\site-packages\rpy2\rinterface_lib\openrlib.py:58
#      56     rlib = _rinterface_cffi.lib
#      57 else:
# ---> 58     rlib = _dlopen_rlib(R_HOME)
#      61 # R macros and functions
#      62 def _get_symbol_or_fallback(symbol: str, fallback: typing.Any):
#
# File c:\Users\KARAN\anaconda3\envs\STAGATE_PT\lib\site-packages\rpy2\rinterface_lib\openrlib.py:51, in _dlopen_rlib(r_home)
#      49     raise ValueError('The library path cannot be None.')
#      50 else:
# ---> 51     rlib = ffi.dlopen(lib_path)
#      52 return rlib
#
# OSError: cannot load library 'C:\Program Files\R\R-4.3.0\bin\x64\R.dll': error 0x780

# %%
adata = STAGATE.mclust_R(adata, used_obsm='STAGATE', num_cluster=7)
obs_df = adata.obs.dropna()
# Out:
# fitting ...
#   |======================================================================| 100%

# %%
plt.rcParams["figure.figsize"] = (5, 5)
sc.pl.umap(adata, color=["mclust"], title=['STAGATE'])

# %%
plt.rcParams["figure.figsize"] = (5, 5)
sc.pl.spatial(adata, color=["mclust"], title=['STAGATE'])
